# %%
# ==========================================================
# PRD to BDD JSON Converter (using OpenAI GPT)
# Author: Arjun M S
# Purpose: Automatically extract BDD scenarios (Given/When/Then)
#          from Product Requirements Documents using LLMs
# ==========================================================

# %%
# !pip install sentence-transformers scikit-learn
# !pip install google-genai python-docx PyPDF2

# %%
import docx
import json
import re
# import openai
from pathlib import Path
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

# Import Gemini / GenAI SDK
from google import genai
from google.genai import types


from google.colab import userdata
GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')


client = genai.Client(api_key=GEMINI_API_KEY)


import PyPDF2
from pathlib import Path
from textwrap import shorten

# %%
# Read PRD File
def read_document(file_path):
    """
    Extracts text from a .docx or .pdf PRD file.
    """
    file_extension = Path(file_path).suffix.lower()

    if file_extension == ".docx":
        doc = docx.Document(file_path)
        text = "\n".join([p.text.strip() for p in doc.paragraphs if p.text.strip()])
    elif file_extension == ".pdf":
        text = ""
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            for page_num in range(len(reader.pages)):
                page = reader.pages[page_num]
                text += page.extract_text() + "\n"
    else:
        raise ValueError(f"Unsupported file type: {file_extension}. Please provide a .docx or .pdf file.")

    return text

# %%
# Split Large Documents into Manageable Chunks (using simple character count)
def chunk_text(text, max_length=4000):
    """Split long text into smaller chunks for API processing."""
    sentences = re.split(r'(?<=[.!?])\s+', text) # look behind for a punctuation mark like ., !, or ?
    chunks, chunk = [], ""
    for s in sentences:
        if len(chunk) + len(s) < max_length: # Add sentence to current chunk (if not too long)
            chunk += " " + s
        else: # If it would exceed the limit, save the chunk
            chunks.append(chunk.strip())
            chunk = s
    if chunk: # Add the last leftover chunk (After the loop, if there’s any text left unsaved, add it to the list.)
        chunks.append(chunk.strip())
    return chunks

# %%
# Uses Gemini to extract Given/When/Then scenarios from text chunk.
def extract_bdd_from_chunk(chunk):

    prompt = f"""
You are a software analyst. Convert the following PRD section into a structured JSON of BDD (Behavior Driven Development) scenarios.

Each scenario should be in the format:
{{
  "given": "...",
  "when": "...",
  "then": "..."
}}

If multiple features or behaviors exist, create multiple scenarios.
Keep the output strictly valid JSON (no commentary, no markdown).

Text:
{chunk}
    """

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt,
        config=types.GenerateContentConfig(response_mime_type="application/json")
    )

    # print("=== TEXT OUT RESPONSE ===")
    try:
        text_out = response.candidates[0].content.parts[0].text.strip()
    except Exception:
        text_out = response.text or ""
    # print(text_out)
    # print("====================")

    # Try to parse structured output
    parsed = getattr(response, "parsed", None)
    if parsed:
        return parsed

    # If parsed is empty, use text_out fallback
    if text_out:
        cleaned = text_out.strip().strip("```json").strip("```")
        print("=== CLEANED RESPONSE ===")
        print(cleaned)
        print("====================")
        print()
        try:
            return json.loads(cleaned)
        except Exception as e:
            print("⚠️ JSON parse failed:", e)
            return {"error": "Invalid JSON", "raw_output": cleaned[:300]}
    else:
        return {"error": "Empty response"}

# %%
# Combine All Scenarios
def prd_to_bdd_json(file_path):
    text = read_document(file_path)
    chunks = chunk_text(text)

    print(f"Processing {len(chunks)} chunks...")

    all_features = []
    for i, chunk in enumerate(chunks, start=1):
        print(f"🔹 Analyzing chunk {i}/{len(chunks)}...")
        result = extract_bdd_from_chunk(chunk)

        if result is None:
            print(f"⚠️ Chunk {i} returned None — skipping")
            continue

        # to handle or normalize different possible output formats from the LLM
        # LLMs (like Gemini or GPT) don’t always respond exactly the same way
        if isinstance(result, dict) and "features" in result: # if the result is a dictionary and features is a key in that dictionary
            all_features.extend(result["features"])
        elif isinstance(result, list): # if the result is a List
            all_features.extend(result)
        else:
            all_features.append(result)

    bdd_data = {"features": all_features}
    return bdd_data

# %%
# Run Conversion
file_path = "Scribl — Product Requirements Document (PRD).docx"
# file_path = "prd2_macrohard.pdf"

bdd_json = prd_to_bdd_json(file_path)
# Out:
# Streaming output truncated to the last 5000 lines.
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'plan_tier' ENUM type exists and contains the values 'NORMAL', 'PRO', 'ENTERPRISE', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'invoice_status' ENUM type exists and contains the values 'PENDING', 'PAID', 'FAILED', 'VOID', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'notification_channel' ENUM type exists and contains the values 'IN_APP', 'EMAIL', 'SLACK', 'TEAMS', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'notification_status' ENUM type exists and contains the values 'PENDING', 'SENT', 'READ', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'webhook_status' ENUM type exists and contains the values 'PENDING', 'PROCESSED', 'FAILED', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'publish_job_status' ENUM type exists and contains the values 'QUEUED', 'RUNNING', 'FAILED', 'SUCCESS', 'CANCELLED', 'DLQ', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'engagement_action' ENUM type exists and contains the values 'LIKE', 'COMMENT', 'SHARE', 'CLICK', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'publish_platform' ENUM type exists and contains the values 'LINKEDIN', 'X', 'INSTAGRAM', 'YOUTUBE', 'FACEBOOK', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'integration_type' ENUM type exists and contains the values 'SLACK', 'CRM', 'CALENDAR', 'SALESFORCE', 'HUBSPOT', 'UNSPLASH', 'PEXELS', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'support_priority' ENUM type exists and contains the values 'LOW', 'MEDIUM', 'HIGH', 'URGENT', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'support_status' ENUM type exists and contains the values 'OPEN', 'PENDING', 'RESOLVED', 'CLOSED', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'compliance_status' ENUM type exists and contains the values 'PASS', 'WARN', 'FAIL', ensuring idempotency."
#   },
#   {
#     "given": "A clean or partially initialized PostgreSQL database.",
#     "when": "The database schema initialization script is executed.",
#     "then": "The 'plagiarism_engine' ENUM type exists and contains the values 'INTERNAL', 'EXTERNAL', ensuring idempotency."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 20/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A user provides a unique email address and other required registration details.",
#     "when": "The user attempts to register for an account.",
#     "then": "A new 'users' record is created with a unique ID, the provided email, and a default 'EDITOR' role."
#   },
#   {
#     "given": "An existing 'users' record with a specific email address.",
#     "when": "Another user attempts to register with the same email address.",
#     "then": "The registration fails, indicating that the email address is already in use."
#   },
#   {
#     "given": "An authenticated user.",
#     "when": "The user creates a new team with a unique name and an optional slug.",
#     "then": "A new 'teams' record is created, the authenticated user is set as the 'owner_id', and the team has a default 'NORMAL' plan and '1' seat_count."
#   },
#   {
#     "given": "An existing team and an existing user who is not a member of that team.",
#     "when": "An administrator invites the user to the team with a specified role.",
#     "then": "A 'team_members' record is created, linking the user and the team with the specified role and an 'invited' status."
#   },
#   {
#     "given": "A user has been invited to a team (a 'team_members' record with status 'invited' exists).",
#     "when": "The user accepts the team invitation.",
#     "then": "The 'status' in the 'team_members' record is updated to 'accepted', and the 'accepted_at' timestamp is recorded."
#   },
#   {
#     "given": "A user is already a member of a specific team.",
#     "when": "An attempt is made to add or invite the same user to the same team again.",
#     "then": "The operation fails due to the unique constraint on 'team_id' and 'user_id' in 'team_members'."
#   },
#   {
#     "given": "A team exists with multiple members linked through 'team_members' records.",
#     "when": "The team is deleted.",
#     "then": "All associated 'team_members' records for that team are automatically deleted due to the 'ON DELETE CASCADE' constraint."
#   },
#   {
#     "given": "An existing team and an existing user.",
#     "when": "A specific seat type is assigned to the user within that team.",
#     "then": "A 'seats' record is created, linking the user to the team with the assigned seat type."
#   },
#   {
#     "given": "A user already has a seat assigned within a specific team.",
#     "when": "An attempt is made to assign another seat to the same user within the same team.",
#     "then": "The operation fails due to the unique constraint on 'team_id' and 'user_id' in 'seats'."
#   },
#   {
#     "given": "A team exists with assigned seats linked through 'seats' records.",
#     "when": "The team is deleted.",
#     "then": "All associated 'seats' records for that team are automatically deleted due to the 'ON DELETE CASCADE' constraint."
#   },
#   {
#     "given": "An existing team.",
#     "when": "A user creates a new workspace within that team, providing a unique name.",
#     "then": "A new 'workspaces' record is created, linked to the specified team."
#   },
#   {
#     "given": "An existing user and an existing workspace.",
#     "when": "The user is granted access to the workspace with a defined 'permission_set'.",
#     "then": "A 'user_workspaces' record is created, linking the user to the workspace with the specified permissions."
#   },
#   {
#     "given": "A user already has access to a specific workspace.",
#     "when": "An attempt is made to grant the same user access to the same workspace again.",
#     "then": "The operation fails due to the unique constraint on 'user_id' and 'workspace_id' in 'user_workspaces'."
#   },
#   {
#     "given": "A user exists and has access to one or more workspaces linked through 'user_workspaces' records.",
#     "when": "The user is deleted.",
#     "then": "All associated 'user_workspaces' records for that user are automatically deleted due to the 'ON DELETE CASCADE' constraint."
#   },
#   {
#     "given": "A workspace exists and has multiple users with access linked through 'user_workspaces' records.",
#     "when": "The workspace is deleted.",
#     "then": "All associated 'user_workspaces' records for that workspace are automatically deleted due to the 'ON DELETE CASCADE' constraint."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 21/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A user is logged in and has permissions to create content.",
#     "when": "The user creates a new content item specifying its type, title, and initial body.",
#     "then": "A new 'content_items' record is created with a 'DRAFT' status, 'version' set to 1, and an initial 'content_versions' record is generated."
#   },
#   {
#     "given": "An existing content item is in 'DRAFT' status.",
#     "when": "The owner updates the content item's body, title, or tags and provides a change reason.",
#     "then": "A new 'content_versions' record is created, the 'content_items' 'version' field is incremented, and 'updated_at' is updated."
#   },
#   {
#     "given": "A user wants to upload an image to be used in content.",
#     "when": "The user provides image details including its source, URL, and metadata.",
#     "then": "A new 'images' record is created, storing the image's information and marking its owner."
#   },
#   {
#     "given": "A 'content_item' exists and an 'images' record is available.",
#     "when": "The user associates the image with the content item at a specified position.",
#     "then": "A new 'content_media' record is created, linking the content item and the image with its positional data."
#   },
#   {
#     "given": "A 'content_item' exists and a file is uploaded to the storage system.",
#     "when": "The user attaches the uploaded file to the content item, providing its filename, content type, and size.",
#     "then": "A new 'attachments' record is created, referencing the content item, and storing the file's metadata and storage path."
#   },
#   {
#     "given": "An administrator is managing a workspace.",
#     "when": "The administrator defines a new approval hierarchy with a unique name and a structured set of approval steps.",
#     "then": "A new 'approval_hierarchies' record is created in the workspace, storing the defined approval workflow."
#   },
#   {
#     "given": "A 'content_item' is in 'DRAFT' status and an 'approval_hierarchy' has been defined.",
#     "when": "A user submits the content item for approval, referencing an existing approval hierarchy.",
#     "then": "A new 'approvals' record is created with a 'PENDING' status, linked to the content item and the specified hierarchy."
#   },
#   {
#     "given": "A 'content_item' is in a 'PENDING' approval state, and it is the designated approver's turn for the current step.",
#     "when": "The designated approver reviews the content and approves the current step.",
#     "then": "The 'approvals' status is updated to the next step or 'APPROVED', and an 'approval_transitions' record is created to log this action."
#   },
#   {
#     "given": "A 'content_item' is in a 'PENDING' approval state, and it is the designated approver's turn for the current step.",
#     "when": "The designated approver reviews the content and rejects the current step, providing comments.",
#     "then": "The 'approvals' status is updated to 'REJECTED', and an 'approval_transitions' record is created to log this action and comments."
#   },
#   {
#     "given": "A 'content_item' has been through several approval transitions.",
#     "when": "A user requests to view the complete approval history for that content item.",
#     "then": "All associated 'approval_transitions' records are retrieved and presented, showing the full workflow progression."
#   },
#   {
#     "given": "A 'content_item' exists and is designated to contain a carousel.",
#     "when": "The user adds a new slide to this content item, providing its body content and specifying its position.",
#     "then": "A new 'carousel_slides' record is created, linked to the content item, and storing the slide's content and order."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 22/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A content item exists and an active platform profile is configured for a workspace.",
#     "when": "A user schedules the content item for a specific future date/time on that platform profile.",
#     "then": "A new 'schedule' record is created with a 'PENDING' status, referencing the content item and platform profile, and without recurrence information."
#   },
#   {
#     "given": "A content item exists and an active platform profile is configured for a workspace.",
#     "when": "A user schedules the content item with a recurring pattern (e.g., weekly) for a specific platform profile.",
#     "then": "A new 'schedule' record is created with a 'PENDING' status, referencing the content item and platform profile, including the recurrence pattern in 'recurrence_json' and setting 'next_run_at' for the first occurrence."
#   },
#   {
#     "given": "A 'schedule' record exists with a 'PENDING' status, and its 'scheduled_at' or 'next_run_at' is in the past.",
#     "when": "The system's scheduling mechanism processes the overdue schedule.",
#     "then": "A 'publish_job' record is created with a 'QUEUED' status, linking to the schedule, content item, and relevant platform profile, and if recurring, the 'schedule's 'next_run_at' is updated for the next occurrence."
#   },
#   {
#     "given": "A 'publish_job' record exists with a 'QUEUED' status.",
#     "when": "A worker picks up the 'publish_job' and successfully publishes the content to the external platform, receiving an external post identifier.",
#     "then": "The 'publish_job's status is updated to 'SUCCESS', 'published_at' is set, and a 'platform_post' record is created linking to the 'publish_job' and containing the external post identifier and platform details."
#   },
#   {
#     "given": "A 'publish_job' record exists with a 'QUEUED' status, and its 'attempt_count' is below the maximum retry limit.",
#     "when": "A worker attempts to execute the 'publish_job' but encounters a recoverable error during publishing.",
#     "then": "A 'job_attempt' record is created detailing the error, the 'publish_job's 'attempt_count' is incremented, 'last_error' is updated, and the 'publish_job's status remains 'QUEUED' (or is set to 'QUEUED' for retry processing)."
#   },
#   {
#     "given": "A 'publish_job' record exists with a 'QUEUED' status, and its 'attempt_count' has reached the maximum retry limit.",
#     "when": "A worker attempts to execute the 'publish_job' and encounters another error.",
#     "then": "A 'job_attempt' record is created detailing the error, 'last_error' is updated, and the 'publish_job's status is updated to 'FAILED'."
#   },
#   {
#     "given": "A user is within their workspace and has credentials or authorization for an external publishing platform (e.g., LinkedIn, Facebook).",
#     "when": "The user connects their external profile to the system.",
#     "then": "A 'platform_profile' or 'linked_in_profile' record is created for the workspace/user, storing the external profile ID and necessary configuration or access tokens."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 23/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "New usage metrics are generated for a specific content item.",
#     "when": "The system processes and records these content item metrics.",
#     "then": "An entry should be created in the 'analytics' table containing the content item ID, the metrics data, and a timestamp."
#   },
#   {
#     "given": "A user performs an action (e.g., like, share, comment) on a content item or an external post, potentially influenced by an AI suggestion.",
#     "when": "The system captures this user engagement.",
#     "then": "A new record should be added to the 'engagements' table, detailing the user, the target (content item or external post), the action type, and linking to an AI suggestion if applicable."
#   },
#   {
#     "given": "A user within a specific workspace requests their personalized engagement feed.",
#     "when": "The system generates the dynamic engagement feed for that user and workspace.",
#     "then": "The generated feed content should be stored in the 'engagement_feed' table, associated with the user and workspace, along with a generation timestamp."
#   },
#   {
#     "given": "The system continuously monitors various data sources within a workspace.",
#     "when": "A new trending topic or signal is identified.",
#     "then": "A new record should be created in the 'trending_signals' table for the respective workspace, including the topic, signal data, a calculated score, and the evaluation timestamp."
#   },
#   {
#     "given": "A user in a workspace wants to monitor a new competitor.",
#     "when": "The user adds a competitor account by providing its external identifier and name.",
#     "then": "A new entry should be created in the 'competitor_accounts' table, containing the workspace ID, competitor details, the user who added it, and the addition timestamp."
#   },
#   {
#     "given": "A monitored competitor account exists.",
#     "when": "The system performs a scheduled or manual snapshot of the competitor's performance.",
#     "then": "A new snapshot record should be created in the 'competitor_snapshots' table, linked to the competitor account, containing the metrics and any raw data from that specific point in time."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 24/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A user initiates an AI feature request, resulting in token consumption.",
#     "when": "The AI model processes the request and generates a response.",
#     "then": "The prompt details, response snippet, tokens used, and estimated cost are logged in the 'ai_prompts' table."
#   },
#   {
#     "given": "An AI prompt has been successfully processed and logged in 'ai_prompts'.",
#     "when": "The system aggregates the AI usage for cost and quota tracking.",
#     "then": "The tokens used and cost estimate are recorded in the 'ai_usage' table for the respective user, workspace, and team."
#   },
#   {
#     "given": "An administrator wants to provide AI credits to a specific team or user.",
#     "when": "The administrator allocates a defined amount of credits.",
#     "then": "A new entry is created in 'ai_credit_allocations' with the total and remaining credits, and a corresponding credit entry is added to the 'ai_credit_ledger'."
#   },
#   {
#     "given": "A user with an active credit allocation uses an AI feature that consumes tokens.",
#     "when": "The AI usage is recorded and its cost is calculated.",
#     "then": "The 'credits_remaining' in the user's or team's 'ai_credit_allocations' is decreased by the cost, and a debit entry is recorded in 'ai_credit_ledger'."
#   },
#   {
#     "given": "A team decides to purchase additional AI credits via a predefined 'ai_credit_packs'.",
#     "when": "The team successfully completes the purchase transaction.",
#     "then": "A 'credit_topups' entry is created with a 'completed' status, the 'credits_total' and 'credits_remaining' in the team's 'ai_credit_allocations' are increased, and a credit entry is recorded in 'ai_credit_ledger'."
#   },
#   {
#     "given": "A team has a daily quota defined for an AI metric in 'quota_counters', and their 'consumed' amount has reached the limit.",
#     "when": "A user from that team attempts to use the AI feature associated with the metric.",
#     "then": "The system prevents the AI feature from being used and informs the user that the quota has been exceeded."
#   },
#   {
#     "given": "A user successfully uses an AI feature that is tied to a specific metric in 'quota_counters'.",
#     "when": "The AI usage is completed and recorded.",
#     "then": "The 'consumed' amount in the relevant 'quota_counters' entry for the team/workspace and metric is incremented by the usage."
#   },
#   {
#     "given": "A user is viewing a help tour within a specific workspace, tracked in 'help_tours'.",
#     "when": "The user completes all steps of the help tour.",
#     "then": "The 'completed_at' timestamp for that 'help_tours' entry is set, indicating the tour's completion for the user in the workspace."
#   },
#   {
#     "given": "Multiple locales are defined in 'locales' and corresponding translations for various keys are available in 'translations'.",
#     "when": "A user selects a specific locale (e.g., 'es-ES') for their interface.",
#     "then": "All displayable text for which a translation exists is presented in the selected locale using data from the 'translations' table."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 25/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A workspace exists and a user with appropriate permissions is logged in.",
#     "when": "The user creates a new integration configuration specifying its type and config_json.",
#     "then": "A new record is created in the 'integrations' table with a unique ID, workspace_id, type, config_json, and an initial status."
#   },
#   {
#     "given": "An active integration exists and an event is received from the integrated service.",
#     "when": "The system processes the incoming integration event.",
#     "then": "A new record is created in the 'integration_events' table, linked to the integration, detailing the event_type, payload, status, and received_at timestamp."
#   },
#   {
#     "given": "A workspace exists and a user with appropriate permissions is logged in.",
#     "when": "The user generates a new API key for their workspace, providing a name and specifying scopes and optional rate limits.",
#     "then": "A new record is created in the 'api_keys' table with a unique ID, workspace_id, name, a hashed key, scopes, rate_limit_json, and marked as active."
#   },
#   {
#     "given": "An active API key exists for a workspace.",
#     "when": "An external service successfully uses the API key to make an authenticated request.",
#     "then": "The 'last_used_at' timestamp for the corresponding 'api_keys' record is updated."
#   },
#   {
#     "given": "A user in a workspace wants to import data.",
#     "when": "The user initiates an import job, providing a file path, import type, and additional parameters.",
#     "then": "A new record is created in the 'import_jobs' table, tracking the workspace_id, user_id, file_path, type, status (e.g., 'PENDING' or 'IN_PROGRESS'), and params_json."
#   },
#   {
#     "given": "A user in a workspace wants to export data.",
#     "when": "The user initiates an export job, specifying the desired file path, format, and additional parameters.",
#     "then": "A new record is created in the 'export_jobs' table, tracking the workspace_id, user_id, file_path, format, status (e.g., 'PENDING' or 'IN_PROGRESS'), and params_json."
#   },
#   {
#     "given": "A stock image provider is configured and available.",
#     "when": "The system fetches and processes metadata for a stock image from the provider.",
#     "then": "A new record is created in the 'stock_image_cache' table, linking to the provider, storing the provider_image_id, and its metadata."
#   },
#   {
#     "given": "A team decides to subscribe to a specific plan.",
#     "when": "The team successfully completes the subscription process, potentially via Stripe.",
#     "then": "A new record is created in the 'subscriptions' table, linking to the team, with the chosen plan, an active status, and the next_billing_at date."
#   },
#   {
#     "given": "An active subscription exists for a team.",
#     "when": "A billing cycle completes, or a change in subscription status occurs (e.g., cancellation, upgrade).",
#     "then": "The 'status' and 'next_billing_at' fields of the corresponding 'subscriptions' record are updated accordingly."
#   },
#   {
#     "given": "An active subscription is due for billing.",
#     "when": "An invoice is generated for the subscription, either by the system or an external billing provider like Stripe.",
#     "then": "A new record is created in the 'invoices' table, linked to the subscription, detailing the amount, status, and a PDF URL."
#   },
#   {
#     "given": "An invoice exists with a pending or unpaid status.",
#     "when": "The payment for the invoice is successfully processed.",
#     "then": "The 'status' of the corresponding 'invoices' record is updated to 'PAID' and the 'paid_at' timestamp is set."
#   },
#   {
#     "given": "An external service sends a webhook event to the system.",
#     "when": "The system receives the incoming webhook payload, provider, event type, and signature.",
#     "then": "A new record is created in the 'webhook_events' table with the payload, provider, event_type, signature, received_at timestamp, and an initial status of 'PENDING'."
#   },
#   {
#     "given": "A 'webhook_events' record exists with a 'PENDING' status.",
#     "when": "The system successfully processes the webhook's payload.",
#     "then": "The 'status' of the 'webhook_events' record is updated to 'PROCESSED' and the 'processed_at' timestamp is set."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 26/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A user performs an action within the system",
#     "when": "The action is successfully completed",
#     "then": "An entry is recorded in the \"audit_logs\" table, detailing the actor, action, target, and relevant metadata"
#   },
#   {
#     "given": "A user encounters an issue or has a question regarding their workspace",
#     "when": "The user submits a new support ticket with a subject and body",
#     "then": "A new entry is created in the \"support_tickets\" table with the requester, workspace, subject, body, and an initial status and priority"
#   },
#   {
#     "given": "A workspace administrator needs to define how long certain data should be kept",
#     "when": "The administrator creates a new retention policy for their workspace, specifying its name and rules",
#     "then": "A new entry is recorded in the \"retention_policies\" table for that workspace"
#   },
#   {
#     "given": "A team has specific data residency requirements for certain regions",
#     "when": "A team administrator configures data residency settings for their team and a specific region",
#     "then": "A record reflecting the region's data residency configuration is stored in the \"region_data_config\" table for that team"
#   },
#   {
#     "given": "A security-sensitive event, such as a failed login attempt or an access change, occurs for a user",
#     "when": "The event is detected by the system",
#     "then": "A new record is created in the \"security_events\" table, capturing the user, event type, and relevant metadata"
#   },
#   {
#     "given": "A new capability or action needs to be controlled within the system",
#     "when": "An administrator defines a new permission with a unique code and description",
#     "then": "The new permission is stored in the \"permissions\" table"
#   },
#   {
#     "given": "An administrator needs to group specific permissions for users within a team or workspace",
#     "when": "The administrator creates a new role, providing a name, description, and optionally specifying its scope (team or workspace)",
#     "then": "The new role is recorded in the \"roles\" table"
#   },
#   {
#     "given": "An existing role and a set of defined permissions",
#     "when": "An administrator assigns one or more permissions to the role",
#     "then": "Entries are created in the \"role_permissions\" table, linking the role and the assigned permissions"
#   },
#   {
#     "given": "An existing user and a defined role",
#     "when": "An administrator assigns a role to a user, optionally specifying a scope (e.g., a specific workspace)",
#     "then": "A new entry is created in the \"user_roles\" table, associating the user with the role and its scope"
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 27/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "an administrator for a team",
#     "when": "they configure a new identity provider and link it to their team",
#     "then": "the system should store the identity provider configuration and the link between the team and the provider"
#   },
#   {
#     "given": "a user belonging to a team",
#     "when": "they create a new brand voice for their team",
#     "then": "the system should store the brand voice details, including its name, description, and associated team"
#   },
#   {
#     "given": "a new user completing their onboarding process",
#     "when": "they specify their goals and optionally select a brand voice",
#     "then": "the system should create an onboarding profile linked to the user and team, capturing their goals and selected brand voice"
#   },
#   {
#     "given": "a user creating a new content template",
#     "when": "they define the template's title, type, and schema",
#     "then": "the system should store the template, associating it with the owner, and setting its initial scope to private"
#   },
#   {
#     "given": "a user with an existing template",
#     "when": "they choose to share the template with another workspace",
#     "then": "the system should record the template share, linking the template to the target workspace and tracking who shared it"
#   },
#   {
#     "given": "a publisher with an approved template",
#     "when": "they decide to list their template in the marketplace with specific pricing",
#     "then": "the system should create a marketplace item for the template, associating it with the publisher and pricing details"
#   },
#   {
#     "given": "an existing content item",
#     "when": "a user requests a plagiarism check for it using a specified engine",
#     "then": "the system should perform the check, store the results including a score, and mark it as checked"
#   },
#   {
#     "given": "an existing content item",
#     "when": "a user requests a compliance check of a specific type for it",
#     "then": "the system should perform the check, store the results, update the status, and mark it as checked"
#   },
#   {
#     "given": "a user within a workspace",
#     "when": "they request to export a report in a specific format with certain parameters",
#     "then": "the system should record the export request, track its status, and eventually store the file path upon completion"
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 28/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "The `public.update_updated_at_column` function is defined.",
#     "when": "Any table with an 'updated_at' column is updated or a new row is inserted into it, and the corresponding trigger is active.",
#     "then": "The 'updated_at' column of the affected row is automatically set to the current timestamp."
#   },
#   {
#     "given": "The `public.update_updated_at_column` function is invoked by a trigger.",
#     "when": "The function begins execution.",
#     "then": "The `search_path` configuration is cleared within the function's context to prevent security vulnerabilities."
#   },
#   {
#     "given": "A set of specified tables (e.g., 'users', 'content_items') exist in the public schema, and some have an 'updated_at' column.",
#     "when": "The idempotent script to attach `update_updated_at_column` triggers is executed.",
#     "then": "A `BEFORE UPDATE` trigger named `update_<table_name>_updated_at` is created for each table that has an 'updated_at' column and does not already have such a trigger."
#   },
#   {
#     "given": "The `public.update_search_tsv` function is defined and an active trigger is set on the 'content_items' table.",
#     "when": "A row in the 'content_items' table is inserted or updated.",
#     "then": "The 'search_tsv' column for that row is populated with a 'tsvector' combining weighted 'title', 'body', and 'tags' content."
#   },
#   {
#     "given": "The `public.update_search_tsv` function is defined and an active trigger is set on the 'templates' table.",
#     "when": "A row in the 'templates' table is inserted or updated.",
#     "then": "The 'search_tsv' column for that row is populated with a 'tsvector' combining weighted 'title' and 'schema_json' content."
#   },
#   {
#     "given": "The `public.update_search_tsv` function is invoked by a trigger.",
#     "when": "The function begins execution.",
#     "then": "The `search_path` configuration is cleared within the function's context to prevent security vulnerabilities."
#   },
#   {
#     "given": "The 'content_items' and 'templates' tables exist.",
#     "when": "The idempotent script to attach `update_search_tsv` triggers is executed.",
#     "then": "`BEFORE INSERT OR UPDATE` triggers named `trg_content_items_search_tsv` and `trg_templates_search_tsv` are created for their respective tables if they do not already exist."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 29/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A content_item exists with a current_version_id referencing a content_version.",
#     "when": "The referenced content_version is deleted.",
#     "then": "The current_version_id in the content_item should be set to NULL."
#   },
#   {
#     "given": "A content_item exists with a created_by field referencing a user.",
#     "when": "The referenced user is deleted.",
#     "then": "The created_by field in the content_item should be set to NULL."
#   },
#   {
#     "given": "A content_item exists with an updated_by field referencing a user.",
#     "when": "The referenced user is deleted.",
#     "then": "The updated_by field in the content_item should be set to NULL."
#   },
#   {
#     "given": "A publish_job exists with a created_by field referencing a user.",
#     "when": "The referenced user is deleted.",
#     "then": "The created_by field in the publish_job should be set to NULL."
#   },
#   {
#     "given": "An approval exists with a created_by field referencing a user.",
#     "when": "The referenced user is deleted.",
#     "then": "The created_by field in the approval should be set to NULL."
#   },
#   {
#     "given": "An approval exists with an updated_by field referencing a user.",
#     "when": "The referenced user is deleted.",
#     "then": "The updated_by field in the approval should be set to NULL."
#   },
#   {
#     "given": "An approval exists with an approver_id field referencing a user.",
#     "when": "The referenced user (approver) is deleted.",
#     "then": "The approver_id field in the approval should be set to NULL."
#   },
#   {
#     "given": "A platform_profile exists with a workspace_id referencing a workspace.",
#     "when": "The referenced workspace is deleted.",
#     "then": "The platform_profile associated with that workspace_id should also be deleted."
#   },
#   {
#     "given": "A publish_job exists with a schedule_id referencing a schedule.",
#     "when": "The referenced schedule is deleted.",
#     "then": "The schedule_id in the publish_job should be set to NULL."
#   },
#   {
#     "given": "A template exists with an owner_id field referencing a user.",
#     "when": "The referenced user (owner) is deleted.",
#     "then": "The owner_id field in the template should be set to NULL."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 30/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "Entities like users, teams, workspaces, content items, content versions, images, content media, schedules, publish jobs, analytics, engagements, AI prompts, AI usage, audit logs, approvals, and platform profiles are stored in the database.",
#     "when": "The system needs to retrieve related data, such as content items belonging to a user/team/workspace, team members for a team/user, content versions for a content item, images for an owner/workspace, or analytics for a content item.",
#     "then": "Database queries involving these relationships and direct lookups by ID columns (e.g., owner_id, team_id, user_id, workspace_id, content_item_id, author_id, image_id, schedule_id, actor_id, approver_id, created_by, updated_by) are executed efficiently, reducing lookup times."
#   },
#   {
#     "given": "Various entities such as users, teams, content items, schedules, publish jobs, and engagements have attributes like `role`, `slug`, `status`, `type`, or `action`.",
#     "when": "The system needs to filter records based on their `role` (users), `slug` (teams), `status` (content items, schedules, publish jobs, notifications), `type` (content items, notifications), or `action` (engagements).",
#     "then": "Database queries for filtering by these common categorical and unique string attributes are executed efficiently."
#   },
#   {
#     "given": "Entities such as content items, content versions, images, schedules, publish jobs, analytics, AI prompts, AI usage, and notifications have timestamps like `created_at`, `recorded_at`, `scheduled_at`, `run_at`, `sent_at`, or `read_at`.",
#     "when": "The system needs to retrieve entities within a specific time range or order them chronologically.",
#     "then": "Database queries involving time-based filtering and ordering are executed efficiently."
#   },
#   {
#     "given": "Content items, templates, competitor snapshots, AI prompts, and integration events store complex, unstructured data in JSONB columns (e.g., metadata, schema_json, metrics_json, context_json, payload).",
#     "when": "The system queries these columns for specific keys, values, or JSON path elements, or performs operations like checking for containment.",
#     "then": "Queries performing lookups and searches within JSONB data are executed efficiently using GIN indexes."
#   },
#   {
#     "given": "Content items can have multiple associated tags stored in an array column (`tags`).",
#     "when": "The system needs to find content items that include specific tags.",
#     "then": "Queries for content items by tag containment are executed efficiently using a GIN index on the `tags` column."
#   },
#   {
#     "given": "Content items and templates include `search_tsv` columns populated with lexemes for full-text indexing.",
#     "when": "Users perform full-text searches for keywords across content or templates.",
#     "then": "Full-text search queries return relevant results quickly and efficiently using GIN indexes on the `search_tsv` columns."
#   },
#   {
#     "given": "A publish job can be created with an `idempotency_key` and associated with a `workspace_id`.",
#     "when": "An attempt is made to create a new publish job with the same `workspace_id` and a non-null `idempotency_key` as an existing job.",
#     "then": "The database prevents the creation of a duplicate publish job, enforcing uniqueness for workspace-level idempotent operations."
#   },
#   {
#     "given": "A publish job can be created with an `idempotency_key` and associated with a `platform_profile_id`.",
#     "when": "An attempt is made to create a new publish job with the same `platform_profile_id` and a non-null `idempotency_key` as an existing job.",
#     "then": "The database prevents the creation of a duplicate publish job, enforcing uniqueness for platform-profile-level idempotent operations."
#   },
#   {
#     "given": "The system manages a queue of publish jobs with different statuses, priorities, and scheduled run times.",
#     "when": "The scheduler service queries for publish jobs that are `QUEUED` and ready to be processed, ordered by priority and run time.",
#     "then": "The query for active publish jobs is highly optimized due to a partial index, allowing the scheduler to efficiently pick the next jobs."
#   },
#   {
#     "given": "Publish jobs can be temporarily leased by workers, with a `lease_expires_at` timestamp.",
#     "when": "The system needs to identify publish jobs whose leases have expired (i.e., `lease_expires_at` is not null and in the past).",
#     "then": "The query for expired leases is executed efficiently due to a partial index, facilitating lease management and re-queuing of jobs."
#   },
#   {
#     "given": "The application requires a mechanism to send and manage notifications to users.",
#     "when": "The database schema is initialized, including the `notifications` table and its associated indexes on `user_id` and `status`.",
#     "then": "The `notifications` table is available with fields for user, type, channel, payload, status, and timestamps, enabling efficient notification storage, retrieval, and management by user or status."
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 31/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "There are 'content_items' rows where 'search_tsv' is NULL",
#     "when": "The 'UPDATE content_items SET updated_at = NOW() WHERE search_tsv IS NULL;' command is executed",
#     "then": "The 'search_tsv' column for those 'content_items' should be updated based on triggers, and their 'updated_at' timestamp should reflect the update"
#   },
#   {
#     "given": "There are 'templates' rows where 'search_tsv' is NULL",
#     "when": "The 'UPDATE templates SET updated_at = NOW() WHERE search_tsv IS NULL;' command is executed",
#     "then": "The 'search_tsv' column for those 'templates' should be updated based on triggers, and their 'updated_at' timestamp should reflect the update"
#   },
#   {
#     "given": "The 'permissions' table does not contain all specified initial permissions",
#     "when": "The initial permission seeding script is executed",
#     "then": "The 'permissions' table should contain all specified default permission codes ('content.create', 'content.edit', etc.) and their descriptions"
#   },
#   {
#     "given": "The 'permissions' table already contains all specified initial permissions",
#     "when": "The initial permission seeding script is executed again",
#     "then": "The 'permissions' table should remain unchanged, without creating duplicate entries or causing errors"
#   },
#   {
#     "given": "The 'locales' table does not contain all specified initial locales",
#     "when": "The initial locale seeding script is executed",
#     "then": "The 'locales' table should contain all specified default locale codes ('en', 'es', 'fr', 'de') and their names"
#   },
#   {
#     "given": "The 'locales' table already contains all specified initial locales",
#     "when": "The initial locale seeding script is executed again",
#     "then": "The 'locales' table should remain unchanged, without creating duplicate entries or causing errors"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to select their own profile from the 'public.users' table",
#     "then": "The user should be able to retrieve their profile data"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to select another user's profile from the 'public.users' table",
#     "then": "The user should not be able to retrieve another user's profile data"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to update their own profile in the 'public.users' table",
#     "then": "The update operation should succeed"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to update another user's profile in the 'public.users' table",
#     "then": "The update operation should fail"
#   },
#   {
#     "given": "A user is authenticated as the owner of a content item",
#     "when": "The user attempts to select their own content item from the 'public.content_items' table",
#     "then": "The user should be able to retrieve their content item"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to select a content item owned by another user from the 'public.content_items' table",
#     "then": "The user should not be able to retrieve the content item"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to insert a new content item with their own user ID as 'owner_id'",
#     "then": "The insert operation should succeed"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to insert a new content item with another user's ID as 'owner_id'",
#     "then": "The insert operation should fail"
#   },
#   {
#     "given": "A user is authenticated as the owner of a content item",
#     "when": "The user attempts to update their own content item in the 'public.content_items' table",
#     "then": "The update operation should succeed"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to update a content item owned by another user in the 'public.content_items' table",
#     "then": "The update operation should fail"
#   },
#   {
#     "given": "A user is authenticated as the owner of a content item",
#     "when": "The user attempts to delete their own content item from the 'public.content_items' table",
#     "then": "The delete operation should succeed"
#   },
#   {
#     "given": "A user is authenticated",
#     "when": "The user attempts to delete a content item owned by another user from the 'public.content_items' table",
#     "then": "The delete operation should fail"
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 32/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A user attempts to access a workspace",
#     "when": "A membership-based policy for workspace access is enforced",
#     "then": "The system checks the 'team_members' table to confirm the user's membership for that team/workspace"
#   },
#   {
#     "given": "Row Level Security policies have been reviewed and tested for a table",
#     "when": "An administrator executes the 'ALTER TABLE ... ENABLE ROW LEVEL SECURITY' command on that table",
#     "then": "The table will enforce row-level security based on its defined policies"
#   },
#   {
#     "given": "A new user begins the authentication process",
#     "when": "The user successfully completes the LinkedIn OAuth flow",
#     "then": "A 'LinkedInProfile' record is created, a 'User' record is created, and the user is assigned to a Team/Workspace context"
#   },
#   {
#     "given": "A 'ContentItem' has been created and any optional approval processes are complete",
#     "when": "The 'ContentItem' is scheduled for publication",
#     "then": "A 'PublishJob' is enqueued, a background worker calls the LinkedIn API, the 'PublishJob.publishedAt' timestamp is marked, and the 'ContentItem' status is updated accordingly"
#   }
# ]
# ====================
#
# 🔹 Analyzing chunk 33/65...
# === CLEANED RESPONSE ===
# [
#   {
#     "given": "A user wants to log in or register via LinkedIn",
#     "when": "They access the LinkedIn OAuth start endpoint with a redirect URL",
#     "then": "The system should redirect them to LinkedIn's authorization page"
#   },
#   {
#     "given": "A user has authorized the application on LinkedIn and been redirected with an authorization code",
#     "when": "The system receives the callback with the authorization code",
#     "then": "The system should exchange the code, create or merge a User and LinkedInProfile, and return a JWT/session along with a User summary"
#   },
#   {
#     "given": "The application is in development mode",
#     "when": "A POST request is made to '/api/auth/demo-login'",
#     "then": "A new demo/test user should be created"
#   },
#   {
#     "given": "A user is authenticated and navigating the onboarding flow",
#     "when": "A POST request is made to '/api/users/:userId/onboarding' with a step and payload",
#     "then": "The user's onboarding progress and preferences should be saved"
#   },
#   {
#     "given": "A user has previously saved onboarding progress",
#     "when": "A GET request is made to '/api/users/:userId/onboarding'",
#     "then": "The system should return the user's current onboarding progress"
#   },
#   {
#     "given": "Content items exist for a workspace with various statuses and tags",
#     "when": "A GET request is made to '/api/contents' with filters for workspaceId, status, and a search query",
#     "then": "A paginated list of matching content items should be returned"
#   },
#   {
#     "given": "An authenticated user and a valid workspace ID",
#     "when": "A POST request is made to '/api/contents' with content details (type, title, body, tags)",
#     "then": "A new ContentItem should be created and returned"
#   },
#   {
#     "given": "An authenticated user and an existing content item ID",
#     "when": "A GET request is made to '/api/contents/:id'",
#     "then": "The details of the specified content item should be returned"
#   },
#   {
#     "given": "An authenticated user and an existing content item ID",
#     "when": "A PATCH request is made to '/api/contents/:id' with updated content details",
#     "then": "The specified content item should be updated with the new details"
#   },
#   {
#     "given": "An authenticated user and an existing content item ID",
#     "when": "A POST request is made to '/api/contents/:id/duplicate'",
#     "then": "A new, identical content item should be created based on the original"
#   },
#   {
#     "given": "An authenticated user and an existing content item ID",
#     "when": "A POST request is made to '/api/contents/:id/versions' with a new body and an optional label",
# ...
#     "when": "Users belonging to the targeted percentage access the application.",
#     "then": "Only the designated percentage of users should see the new feature, while others do not."
#   },
#   {
#     "given": "A product manager wants to test two variants of a new UI component.",
#     "when": "The product manager configures an A/B test, assigning users randomly to Variant A or Variant B.",
#     "then": "Users should be consistently assigned to their variant, and user interactions with each variant should be tracked for analysis."
#   },
#   {
#     "given": "An A/B test has been running for a sufficient period.",
#     "when": "The product manager reviews the experiment dashboard and statistical reporting.",
#     "then": "The system should display clear metrics and statistical significance to help determine the winning variant."
#   },
#   {
#     "given": "A user's browser language is set to French, or they select French from a language picker.",
#     "when": "The user accesses the application.",
#     "then": "All UI text and messages should be displayed in French, using the appropriate translation keys."
#   },
#   {
#     "given": "A user is viewing financial data in a region that uses EUR and DD/MM/YYYY date format.",
#     "when": "The user accesses a report displaying monetary values and dates.",
#     "then": "All monetary values should be formatted with the Euro symbol, and dates should adhere to the DD/MM/YYYY format."
#   },
#   {
#     "given": "A user is logged in.",
#     "when": "The user updates their personal preferences, such as their UI theme from light to dark.",
#     "then": "The user interface should immediately switch to the dark theme, and the preference should persist."
#   },
#   {
#     "given": "An organization has a default setting for password complexity.",
#     "when": "An organization administrator configures a more stringent password complexity policy for their organization.",
#     "then": "All new user accounts within that organization should be required to meet the organization-specific password complexity policy."
#   },
#   {
#     "given": "A user is viewing a document.",
#     "when": "The user adds an inline comment and uses an '@mention' to tag a colleague.",
#     "then": "The comment should be saved, and the mentioned colleague should receive a notification about the comment."
#   },
#   {
#     "given": "An existing comment has been posted on a task.",
#     "when": "Another user replies to that specific comment.",
#     "then": "The reply should be nested under the original comment, forming a threaded discussion."
#   },
#   {
#     "given": "A customer wants to book an appointment with a service provider.",
#     "when": "The customer uses the booking widget to select an available time slot.",
#     "then": "The appointment should be successfully booked, and both the customer and service provider should receive confirmation and calendar invites."
#   },
#   {
#     "given": "A user has a meeting scheduled in the application.",
#     "when": "The user configures calendar synchronization with their Google Calendar.",
#     "then": "The meeting should appear automatically in the user's Google Calendar, and updates should reflect both ways."
#   },
#   {
#     "given": "An item's current stock level is 10 units.",
#     "when": "A new order for 2 units of that item is processed.",
#     "then": "The stock level for that item should be reduced to 8 units."
#   },
#   {
#     "given": "A product has a reorder threshold set at 5 units.",
#     "when": "The stock level for that product drops to 4 units after an order.",
#     "then": "The system should automatically trigger a reorder alert or create a purchase request for that product."
#   },
#   {
#     "given": "A sales representative has configured a new service package for a prospect.",
#     "when": "The representative generates a quote based on the service package.",
#     "then": "A professional quote document should be generated, detailing pricing and terms, ready to be sent to the prospect."
#   },
#   {
#     "given": "A new contract has been drafted and requires approval.",
#     "when": "The contract is submitted for approval, and the approver reviews and approves it.",
#     "then": "The contract status should change to 'Approved', and the approval history should be logged."
#   },
#   {
#     "given": "A department needs to order new office supplies from an approved supplier.",
#     "when": "A user creates a new purchase order (PO) for the supplies and selects the supplier.",
#     "then": "A new PO should be generated and submitted for internal approval before being sent to the supplier."
#   },
#   {
#     "given": "A procurement manager needs to onboard a new supplier.",
#     "when": "The manager adds the new supplier's details to the supplier directory.",
#     "then": "The new supplier's information should be stored, allowing their selection for future procurement activities."
#   },
#   {
#     "given": "A new employee joins the company.",
#     "when": "An HR administrator creates a new employee profile, populating their details and role.",
#     "then": "The new employee profile should be successfully created and added to the company directory and org chart."
#   },
#   {
#     "given": "An employee needs to request vacation leave.",
#     "when": "The employee submits a leave request through the system.",
#     "then": "The leave request should be routed to their manager for approval, and their availability updated."
#   },
#   {
#     "given": "An employee completes several tasks throughout the day.",
#     "when": "The employee manually enters their work hours against specific projects/tasks in their timesheet.",
#     "then": "The entered time should be recorded and available for timesheet submission and reporting."
#   },
#   {
#     "given": "An employee has submitted their weekly timesheet for approval.",
#     "when": "The employee's manager reviews and approves the submitted timesheet.",
#     "then": "The timesheet status should change to 'Approved', making it eligible for payroll/billing processing."
#   },
#   {
#     "given": "Employee timesheets have been approved and salary rules are configured.",
#     "when": "The payroll administrator initiates the monthly payroll run.",
#     "then": "Payslips for all employees should be accurately generated, reflecting salary, taxes, and deductions."
#   },
#   {
#     "given": "A payroll run is initiated for employees in different tax jurisdictions.",
#     "when": "The system calculates the net pay for each employee.",
#     "then": "The system should accurately apply the correct tax calculations (e.g., income tax, social security) based on each employee's jurisdiction."
#   },
#   {
#     "given": "A tenant has a storage quota of 10GB.",
#     "when": "The tenant attempts to upload files that would exceed their 10GB quota.",
#     "then": "The system should prevent the upload and notify the tenant that their storage quota has been reached."
#   },
#   {
#     "given": "An API endpoint has a throttle limit of 5 requests per second per user.",
#     "when": "A user makes 6 requests to that endpoint within one second.",
#     "then": "The 6th request should be rejected by the system due to API throttling."
#   },
#   {
#     "given": "A customer support ticket has an SLA for 'first response within 4 hours'.",
#     "when": "4 hours pass without a first response to the ticket.",
#     "then": "The system should automatically trigger an SLA breach alert to the support team and relevant managers."
#   },
#   {
#     "given": "A customer's service experiences prolonged downtime resulting in an SLA breach.",
#     "when": "The system processes the monthly billing for the customer.",
#     "then": "The system should automatically calculate and apply appropriate service credits to the customer's invoice based on the defined SLA terms."
#   },
#   {
#     "given": "A new user registers for the service.",
#     "when": "The user explicitly accepts the Terms of Service and Privacy Policy.",
#     "then": "The system should record the user's consent, including the timestamp and version of the legal documents accepted."
#   },
#   {
#     "given": "A user (data subject) requests an export of all their personal data as per GDPR.",
#     "when": "The data subject request workflow is initiated and processed.",
#     "then": "The system should provide the user with an export of their personal data in a portable format."
#   },
#   {
#     "given": "A GRC manager needs to publish a new internal security policy.",
#     "when": "The manager drafts the policy using the policy library and submits it for approval.",
#     "then": "The policy should undergo the defined approval workflow and, once approved, be published and accessible to relevant employees."
#   },
#   {
#     "given": "A compliance control is scheduled for periodic testing.",
#     "when": "An auditor performs the control test and records the results.",
#     "then": "The system should track the control's testing status, results, and any identified deficiencies."
#   },
#   {
#     "given": "The application experiences a sudden surge in user traffic.",
#     "when": "The configured autoscaling policy detects a sustained increase in CPU utilization above the threshold.",
#     "then": "The system should automatically provision additional server instances to handle the increased load."
#   },
#   {
#     "given": "A frequently accessed data query is expensive to run.",
#     "when": "The application retrieves data from the cache for this query.",
#     "then": "The data should be returned significantly faster compared to hitting the database directly, improving response times."
#   },
#   {
#     "given": "A developer wants to integrate with the platform using a supported language.",
#     "when": "The developer uses the official SDK provided for their chosen language.",
#     "then": "The developer should be able to easily make API calls and interact with the platform using the SDK's functionalities."
#   },
#   {
#     "given": "A developer wants to test an API endpoint without writing code.",
#     "when": "The developer uses the interactive API playground to make a request to the endpoint.",
#     "then": "The playground should display the API response, helping the developer understand the API's behavior."
#   },
#   {
#     "given": "A user wants to extend platform functionality with a third-party app from the marketplace.",
#     "when": "The user selects an app and initiates its installation.",
#     "then": "The app should be successfully installed within the user's account, requesting necessary permissions, and becoming available for use."
#   },
#   {
#     "given": "A third-party app requests access to specific user data.",
#     "when": "The user grants only the requested permissions during installation.",
#     "then": "The app should only be able to access the data covered by the granted permissions, ensuring data isolation."
#   },
#   {
#     "given": "A security auditor needs to review user access over the past quarter.",
#     "when": "The auditor generates a user access report for the specified period.",
#     "then": "The report should detail which users accessed what resources and when, available for export."
#   },
#   {
#     "given": "An organization needs to prepare for a regulatory audit.",
#     "when": "An administrator uses a pre-built compliance template to generate a report.",
#     "then": "The system should produce a report that aligns with the requirements of the compliance standard, simplifying the audit process."
#   },
#   {
#     "given": "A user has recently used a key feature.",
#     "when": "The system presents an NPS survey to the user.",
#     "then": "The user's NPS score should be recorded, contributing to the overall NPS calculation and analytics."
#   },
#   {
#     "given": "A survey has collected multiple responses from users.",
#     "when": "A product manager reviews the survey response analytics.",
#     "then": "The system should provide insights into user feedback, including sentiment analysis and common themes."
#   },
#   {
#     "given": "A new user logs in for the first time.",
#     "when": "The user completes the initial interactive walkthrough.",
#     "then": "The onboarding checklist should mark completed steps, and the user should gain a basic understanding of core functionalities."
#   },
#   {
#     "given": "A user hovers over an unfamiliar UI element.",
#     "when": "The user's mouse pointer remains on the element for a short duration.",
#     "then": "A tooltip should appear, providing contextual help and explanation for that specific UI element."
#   },
#   {
#     "given": "A user interacts with a new feature.",
#     "when": "The user performs an action within that feature (e.g., clicks a button).",
#     "then": "The system should log an event, recording the feature usage for product analytics."
#   },
#   {
#     "given": "A product manager wants to understand user conversion through a multi-step process.",
#     "when": "The product manager views the funnel analysis report.",
#     "then": "The report should visually represent user drop-off at each step, identifying potential areas for improvement."
#   },
#   {
#     "given": "A user wants to export all their personal data for portability.",
#     "when": "The user initiates a data export, selecting the datasets they wish to include.",
#     "then": "The system should generate an encrypted export file containing the selected data in a standard format (e.g., JSON, CSV)."
#   },
#   {
#     "given": "A data export job has been completed.",
#     "when": "An administrator reviews the audit logs for data exports.",
#     "then": "The audit logs should show details of the export job, including who initiated it, what data was exported, and when."
#   },
#   {
#     "given": "A customer is checking out with a subscription.",
#     "when": "The customer applies a valid coupon code during checkout.",
#     "then": "The system should apply the discount specified by the coupon code to the total price, showing the updated amount."
#   },
#   {
#     "given": "A service uses tiered pricing where the first 100 units are free, and subsequent units cost $1 each.",
#     "when": "A customer uses 150 units of the service.",
#     "then": "The pricing engine should correctly calculate the charge as $50 (150 - 100 free units = 50 units * $1)."
#   },
#   {
#     "given": "A platform operator is logged into the superadmin console.",
#     "when": "The operator views the global health status dashboard.",
#     "then": "The dashboard should display the current operational status of all key platform components and services."
#   },
#   {
#     "given": "A specific tenant requires a temporary increase in their usage quota.",
#     "when": "A super-administrator applies a quota override for that tenant via the superadmin console.",
#     "then": "The tenant's usage quota should be temporarily adjusted, superseding the default quota for their plan."
#   },
#   {
#     "given": "A critical service outage occurs.",
#     "when": "An incident manager creates an incident and publishes an update to the public status page.",
#     "then": "The public status page should immediately reflect the incident and its current status, informing users."
#   },
#   {
#     "given": "A major incident is ongoing, and users have subscribed to status updates.",
#     "when": "The incident manager posts a new update on the status page.",
#     "then": "All subscribed users should receive an email or SMS notification with the latest incident update."
#   },
#   {
#     "given": "A high-value purchase request is submitted.",
#     "when": "The request goes through a multi-step approval workflow involving a team lead and a department head.",
#     "then": "Each approver should receive a notification, and the request should only proceed to the next step after the current approver approves it."
#   },
#   {
#     "given": "An approval request has been pending with an approver for longer than the defined SLA.",
#     "when": "The auto-escalation policy is triggered.",
#     "then": "The request should be automatically escalated to the next level of management, and the original approver should receive a reminder."
#   }
# ]
# ====================

# %%
print(bdd_json)
# print()
# print(type(bdd_json))
# print()
print(f"before deduplication bdd_json:=  {len(bdd_json['features'])}")
# Out:
# {'features': [{'given': 'A new user accesses the Scribl platform.', 'when': 'The user attempts to sign in via LinkedIn OAuth.', 'then': 'The system retrieves their LinkedIn profile data (name, title, connections, profile picture) AND creates a new Scribl user record.'}, {'given': 'A new Scribl user has successfully authenticated via LinkedIn.', 'when': 'The user progresses through the guided, multi-step onboarding flow, providing their goals, brand voice preferences, posting frequency, and niche selections.', 'then': 'The system auto-saves their progress at each step to prevent drop-offs AND records their preferences for future content generation.'}, {'given': 'A Team Admin is configuring a team workspace and selecting a subscription plan.', 'when': 'The Admin selects the desired number of seats and a subscription plan AND completes the payment process via Stripe.', 'then': 'The system displays real-time pricing and features during selection AND provisions access for the purchased seats upon successful payment.'}, {'given': 'A user is within the Scribl content creation interface (Chat Canvas).', 'when': 'The user inputs an idea or prompt into the AI Assistant.', 'then': "The AI generates multiple variations of posts, articles, or captions aligned with the user's brand voice AND allows the user to refine the drafts through iterative feedback."}, {'given': 'A user is creating a new post.', 'when': 'They drag a text block, image, or design element onto the canvas.', 'then': 'The element is successfully placed and editable.'}, {'given': 'A user has text in a post editor.', 'when': 'They select the text and apply a formatting option (e.g., bold, italics).', 'then': 'The text is formatted as selected.'}, {'given': 'A user has content in the post editor.', 'when': 'They activate the preview function.', 'then': 'They see an accurate representation of how the post will appear on LinkedIn.'}, {'given': 'A user is creating a new post.', 'when': 'They browse and select a pre-designed template categorized by use case or industry.', 'then': "The post editor is populated with the selected template's structure."}, {'given': 'A user has designed a post structure.', 'when': 'They choose to save it as a custom template for team-wide reuse.', 'then': 'The custom template is available for other team members to select when creating new content.'}, {'given': 'A user wants to create a multi-slide LinkedIn carousel.', 'when': 'They select a carousel template (e.g., storytelling, step-by-step guide).', 'then': 'The Carousel Creator provides the appropriate structure and tools for carousel content.'}, {'given': 'A user is designing a carousel in the Carousel Creator.', 'when': 'They view the live preview.', 'then': 'The preview accurately reflects how the carousel will appear on LinkedIn, adhering to format requirements.'}, {'given': 'A user is in the Content Library.', 'when': 'They apply filters by status, content type, or tags.', 'then': 'The library displays only content items matching the applied filters.'}, {'given': 'A user has selected multiple content items in the Content Library.', 'when': 'They initiate a bulk action (e.g., delete, duplicate, export).', 'then': 'The selected action is applied to all chosen content items.'}, {'given': 'An editor has drafted content.', 'when': 'They submit the content for review.', 'then': "The content status changes to 'pending approval' and is visible to approvers."}, {'given': 'An approver is reviewing content submitted for approval.', 'when': 'They add comments, request changes, or approve the content.', 'then': "The content's status and history are updated accordingly, and if approved, it moves to scheduling."}, {'given': 'A user edits and saves a content draft multiple times.', 'when': 'They access the version history.', 'then': 'Each save action has created a new, distinct version of the content.'}, {'given': 'A user has multiple versions of a content item.', 'when': 'They select an older version and cho ...
#
# <class 'dict'>
#
# before deduplication bdd_json:=  1206

# %% [markdown]
# # again pass the bdd_json to an LLM with a predefined prompt to check for duplicates and clean it. (LLM Approach)👇

# %%
# ------------------------------------------------------
# Use LLM to check for duplicates and clean
# ------------------------------------------------------

# import json
# from google import genai
# from google.genai import types

# def clean_duplicates_with_llm(bdd_json_data, client):
#     """
#     Uses an LLM to identify and remove duplicate BDD scenarios.
#     """
#     prompt = f"""
# You are a software analyst tasked with reviewing BDD scenarios.
# The following JSON contains a list of BDD scenarios. Your goal is to identify and remove any scenarios that are semantically duplicate or very similar to others in the list.
# Consider scenarios duplicates if they describe the same behavior or requirement, even if worded slightly differently.
# Keep only one instance of each unique scenario.
# Maintain the original structure of the JSON, returning a list of unique scenarios under the "features" key.

# Input JSON:
# {json.dumps(bdd_json_data, indent=2, ensure_ascii=False)}

# Output JSON (cleaned, with duplicates removed):
# """

#     response = client.models.generate_content(
#         model="gemini-2.5-flash", # Or another suitable model
#         contents=prompt,
#         config=types.GenerateContentConfig(response_mime_type="application/json")
#     )

#     try:
#         cleaned_json_string = response.candidates[0].content.parts[0].text.strip()
#         # Clean up potential markdown formatting
#         cleaned_json_string = cleaned_json_string.strip("```json").strip("```")
#         cleaned_data = json.loads(cleaned_json_string)
#         return cleaned_data
#     except Exception as e:
#         print(f"⚠️ LLM cleanup failed: {e}")
#         # Fallback to returning original data or handle error appropriately
#         return bdd_json_data

# # Example usage (assuming 'client' is already defined from previous cells):
# cleaned_bdd_json = clean_duplicates_with_llm(bdd_json, client)
# print(f"\n✅ Scenarios after LLM cleanup: {len(cleaned_bdd_json['features'])}")
# Out:
# ⚠️ LLM cleanup failed: Unterminated string starting at: line 224 column 16 (char 10881)
#
# ✅ Scenarios after LLM cleanup: 1206

# %% [markdown]
# # ------------- NEW CODE STARTS HERE ⬇️------------------------------

# %%
# ======================================================
# 🔍 BDD Step Semantic Similarity + NLI Relationship Check
# ======================================================

from sentence_transformers import SentenceTransformer, util
from transformers import pipeline
import itertools
import torch

# %%
# ------------------------------------------------------
# 1. Extract BDD step text from your structure
# ------------------------------------------------------
bdd_features = bdd_json.get("features", [])

# Flatten all Given/When/Then steps into simple text lines (compare individual clauses)
bdd_steps = []
for feature in bdd_features:
    for key in ["given", "when", "then"]:
        text = feature.get(key) # Extracts individual Given/When/Then steps as separate text lines
        if text:
            bdd_steps.append(f"{key.capitalize()}: {text}")

# combine into one sentence (less accurate)  (maybe due to weights of given when then)
# bdd_steps = []
# for feature in bdd_features:
#     step_text = f"Given {feature.get('given', '')} When {feature.get('when', '')} Then {feature.get('then', '')}".strip()
#     bdd_steps.append(step_text)

print(f"✅ Extracted {len(bdd_steps)} total BDD steps for comparison.\n")
# Out:
# ✅ Extracted 2217 total BDD steps for comparison.

# %%
print(bdd_features)
# Out:
# [{'given': 'A user is not authenticated with Scribl', 'when': 'The user attempts to sign in via LinkedIn OAuth', 'then': "The system retrieves the user's LinkedIn profile data (name, title, connections, profile picture), and the system creates a Scribl user record"}, {'given': 'A new user has successfully authenticated with Scribl', 'when': 'The user starts the multi-step onboarding flow and provides goals, brand voice, posting frequency, and niche selections', 'then': "The system saves the user's progress automatically, and the user's preferences are configured"}, {'given': 'A new user is in the middle of the multi-step onboarding flow', 'when': 'The user closes the application or navigates away', 'then': "The system saves the user's current onboarding progress, allowing them to resume from where they left off later"}, {'given': 'A Marketing Manager (Team Admin) is configuring their team account', 'when': 'The admin selects the desired number of seats and a subscription plan', 'then': 'A real-time calculator displays the pricing and features, and the system processes payment via Stripe, and access is provisioned for the selected seats'}, {'given': 'A user has configured their brand voice preferences', 'when': 'The user inputs an idea or prompt into the AI Assistant conversational interface', 'then': "The AI generates multiple variations of posts, articles, or captions aligned with the user's brand voice, and the user can refine the generated drafts"}, {'given': 'A user is generating content using the AI Assistant', 'when': 'The user is presented with the Chat Canvas', 'then': 'The user can interact with the AI via the chat panel and simultaneously use the visual editor to modify the content'}, {'given': 'A user is creating or editing a post', 'when': 'The user drags and drops a text block, image, or design element onto the canvas', 'then': 'The element is moved to the new position within the post'}, {'given': 'A user is editing a text block within a post', 'when': 'The user applies formatting (e.g., bold, italics, font size)', 'then': 'The selected text is formatted accordingly'}, {'given': 'A user is creating or editing a post', 'when': 'The user views the preview of the post', 'then': 'The post is displayed exactly as it would appear on LinkedIn'}, {'given': 'A user is creating a new post', 'when': 'The user browses available templates', 'then': 'Templates are categorized by use case (e.g., thought leadership, product launch) and industry'}, {'given': 'A user is creating a new post', 'when': 'The user selects a pre-designed template', 'then': 'The post content area is pre-filled with the structure and elements of the chosen template'}, {'given': 'A user has created a post or modified an existing template', 'when': 'The user saves the current post structure as a custom template', 'then': 'The custom template is saved and made available for reuse by the entire team'}, {'given': 'A user wants to create a multi-slide LinkedIn carousel', 'when': 'The user accesses the Carousel Creator', 'then': 'The user can add and arrange multiple slides for a carousel post'}, {'given': 'A user is creating a carousel post', 'when': 'The user browses templates within the Carousel Creator', 'then': 'Templates specifically designed for storytelling, step-by-step guides, or product showcases are available'}, {'given': 'A user navigates to the Content Library', 'when': 'The content library loads', 'then': 'All content items are displayed in a centralized repository'}, {'given': 'A user is viewing the Content Library', 'when': 'The user applies filters for status (draft, scheduled, published), content type, or tags', 'then': 'Only content items matching the applied filters are displayed'}, {'given': 'A user is viewing the Content Library and has selected multiple content items', 'when': 'The user initiates a bulk delete action', 'then': 'All selected content items are removed from the library'}, {'given': 'An editor has finished creating or editing  ...

# %%
print(bdd_steps)
# Out:
# ['Given: A user is not authenticated with Scribl', 'When: The user attempts to sign in via LinkedIn OAuth', "Then: The system retrieves the user's LinkedIn profile data (name, title, connections, profile picture), and the system creates a Scribl user record", 'Given: A new user has successfully authenticated with Scribl', 'When: The user starts the multi-step onboarding flow and provides goals, brand voice, posting frequency, and niche selections', "Then: The system saves the user's progress automatically, and the user's preferences are configured", 'Given: A new user is in the middle of the multi-step onboarding flow', 'When: The user closes the application or navigates away', "Then: The system saves the user's current onboarding progress, allowing them to resume from where they left off later", 'Given: A Marketing Manager (Team Admin) is configuring their team account', 'When: The admin selects the desired number of seats and a subscription plan', 'Then: A real-time calculator displays the pricing and features, and the system processes payment via Stripe, and access is provisioned for the selected seats', 'Given: A user has configured their brand voice preferences', 'When: The user inputs an idea or prompt into the AI Assistant conversational interface', "Then: The AI generates multiple variations of posts, articles, or captions aligned with the user's brand voice, and the user can refine the generated drafts", 'Given: A user is generating content using the AI Assistant', 'When: The user is presented with the Chat Canvas', 'Then: The user can interact with the AI via the chat panel and simultaneously use the visual editor to modify the content', 'Given: A user is creating or editing a post', 'When: The user drags and drops a text block, image, or design element onto the canvas', 'Then: The element is moved to the new position within the post', 'Given: A user is editing a text block within a post', 'When: The user applies formatting (e.g., bold, italics, font size)', 'Then: The selected text is formatted accordingly', 'Given: A user is creating or editing a post', 'When: The user views the preview of the post', 'Then: The post is displayed exactly as it would appear on LinkedIn', 'Given: A user is creating a new post', 'When: The user browses available templates', 'Then: Templates are categorized by use case (e.g., thought leadership, product launch) and industry', 'Given: A user is creating a new post', 'When: The user selects a pre-designed template', 'Then: The post content area is pre-filled with the structure and elements of the chosen template', 'Given: A user has created a post or modified an existing template', 'When: The user saves the current post structure as a custom template', 'Then: The custom template is saved and made available for reuse by the entire team', 'Given: A user wants to create a multi-slide LinkedIn carousel', 'When: The user accesses the Carousel Creator', 'Then: The user can add and arrange multiple slides for a carousel post', 'Given: A user is creating a carousel post', 'When: The user browses templates within the Carousel Creator', 'Then: Templates specifically designed for storytelling, step-by-step guides, or product showcases are available', 'Given: A user navigates to the Content Library', 'When: The content library loads', 'Then: All content items are displayed in a centralized repository', 'Given: A user is viewing the Content Library', 'When: The user applies filters for status (draft, scheduled, published), content type, or tags', 'Then: Only content items matching the applied filters are displayed', 'Given: A user is viewing the Content Library and has selected multiple content items', 'When: The user initiates a bulk delete action', 'Then: All selected content items are removed from the library', 'Given: An editor has finished creating or editing content', 'When: The editor submits the content for review', "Then: The content's status changes to 'Awaiting Approval', and approvers are  ...

# %%
# ------------------------------------------------------
# 2. Load models (with GPU support if available)
# ------------------------------------------------------
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}\n")

embedder = SentenceTransformer('all-mpnet-base-v2', device=device) # For generating semantic embeddings
nli_model = pipeline("text-classification", model="roberta-large-mnli", device=0 if device=='cuda' else -1) # For Natural Language Inference  (classifies as entailment/contradiction/neutral)
# Out:
# Using device: cpu
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/688 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
# ------------------------------------------------------
# 3. Generate all unique pairs of BDD steps
# This is O(n²) - could be very slow for large documents
# ------------------------------------------------------
pairs = list(itertools.combinations(bdd_steps, 2))
print(f"Total pairs to compare: {len(pairs)}")
# Out:
# Total pairs to compare: 2456436

# %%
from tqdm.notebook import tqdm

# ------------------------------------------------------
# 4. Optimized: Compute similarity and NLI relationship
"""
This code compares every possible pair of BDD steps by computing cosine similarity between their sentence embeddings and,
when similarity is high, uses a Natural Language Inference (NLI) model to classify their relationship (e.g., entailment, contradiction, neutral),
then records the result (similarity score, NLI label, confidence, and decision) for each pair.
"""
# ------------------------------------------------------

# Cache embeddings once
print("Encoding all steps once for efficiency...")
embeddings = embedder.encode(bdd_steps, convert_to_tensor=True)
print("✅ Embeddings ready.\n")

results = []

# Precompute all cosine similarities
cosine_matrix = util.pytorch_cos_sim(embeddings, embeddings)

# Loop through pairs with progress bar
for i, (s1, s2) in enumerate(tqdm(pairs, desc="Comparing pairs")):
    idx1 = bdd_steps.index(s1)
    idx2 = bdd_steps.index(s2)
    sim_score = cosine_matrix[idx1][idx2].item()

    # Only run NLI if sentences are somewhat similar (saves time)
    # Only runs expensive NLI model if similarity > 0.6
    if sim_score > 0.6:
        nli_input = s1 + " </s> " + s2
        nli_result = nli_model(nli_input)[0]
        label, conf = nli_result['label'], nli_result['score']
    else:
        label, conf = "NEUTRAL", 1.0  # Skip unnecessary NLI calls

    # Decision logic
    if sim_score > 0.8:
        if label == 'ENTAILMENT':
            decision = "✅ Likely Duplicate" # High similarity (>0.8) + entailment = duplicate
        elif label == 'CONTRADICTION':
            decision = "❌ Contradictory" # High similarity + contradiction = conflicting requirements
        else:
            decision = "⚠️ Similar but Unclear" # High similarity + neutral = needs review
    else:
        decision = "❌ Not Similar" # Low similarity = different scenarios

    results.append({
        'Step 1': s1,
        'Step 2': s2,
        'Similarity': round(sim_score, 4),
        'NLI Label': label,
        'Confidence': round(conf * 100, 2),
        'Decision': decision
    })
# Out:
# Encoding all steps once for efficiency...
# ✅ Embeddings ready.
# Comparing pairs:   0%|          | 0/2456436 [00:00<?, ?it/s]

# %%
# ------------------------------------------------------
# 5. Create and display results table
# ------------------------------------------------------
df_results = pd.DataFrame(results)
pd.set_option('display.max_colwidth', None)  # so full steps are visible
display(df_results)
# Out:
#                                                                                                                 Step 1  \
# 0                                                                       Given: A user is not authenticated with Scribl
# 1                                                                       Given: A user is not authenticated with Scribl
# 2                                                                       Given: A user is not authenticated with Scribl
# 3                                                                       Given: A user is not authenticated with Scribl
# 4                                                                       Given: A user is not authenticated with Scribl
# ...                                                                                                                ...
# 2456431  Then: A complete audit trail of who approved/rejected, when, and any associated comments should be maintained
# 2456432  Then: A complete audit trail of who approved/rejected, when, and any associated comments should be maintained
# 2456433                                                   Given: An approval workflow involves dynamic decision-making
# 2456434                                                   Given: An approval workflow involves dynamic decision-making
# 2456435                                                                     When: Conditional approvals are configured
#
#                                                                                                                                                        Step 2  \
# 0                                                                                                       When: The user attempts to sign in via LinkedIn OAuth
# 1        Then: The system retrieves the user's LinkedIn profile data (name, title, connections, profile picture), and the system creates a Scribl user record
# 2                                                                                                Given: A new user has successfully authenticated with Scribl
# 3                               When: The user starts the multi-step onboarding flow and provides goals, brand voice, posting frequency, and niche selections
# 4                                                         Then: The system saves the user's progress automatically, and the user's preferences are configured
# ...                                                                                                                                                       ...
# 2456431                                                                                                            When: Conditional approvals are configured
# 2456432    Then: The workflow should adjust its path or require additional approvals based on specific criteria within the request (e.g., amount, department)
# 2456433                                                                                                            When: Conditional approvals are configured
# 2456434    Then: The workflow should adjust its path or require additional approvals based on specific criteria within the request (e.g., amount, department)
# 2456435    Then: The workflow should adjust its path or require additional approvals based on specific criteria within the request (e.g., amount, department)
#
#          Similarity      NLI Label  Confidence         Decision
# 0            0.3181        NEUTRAL      100.00    ❌ Not Similar
# 1            0.5064        NEUTRAL      100.00    ❌ Not Similar
# 2            0.8241  CONTRADICTION       99.25  ❌ Contradictory
# 3            0.0841        NEUTRAL      100.00    ❌ Not Similar
# 4            0.0481        NEUTRAL      100.00    ❌ Not Similar
# ...             ...            ...         ...              ...
# 2456431      0.3769        NEUTRAL      100.00    ❌ Not Similar
# 2456432      0.4269        NEUTRAL      100.00    ❌ Not Similar
# 2456433      0.4849        NEUTRAL      100.00    ❌ Not Similar
# 2456434      0.5097        NEUTRAL      100.00    ❌ Not Similar
# 2456435      0.4045        NEUTRAL      100.00    ❌ Not Similar
#
# [2456436 rows x 6 columns]

# %%
# Calculate and print the requested metrics
total_count = len(bdd_steps) # Total number of individual steps
duplicate_count = df_results[df_results['Decision'] == '✅ Likely Duplicate'].shape[0] # Count of pairs marked as likely duplicates
contradicting_count = df_results[df_results['Decision'] == '❌ Contradictory'].shape[0] # Count of pairs marked as contradictory

# "After Cleanup" is the number of unique scenarios, which was already calculated and printed in the remove_duplicates function
scenarios_after_cleanup = len(bdd_json['features'])


print(f"\n--- Summary of BDD Step Analysis ---")
print(f"Total individual steps analyzed: {total_count}")
print(f"Pairs identified as Likely Duplicates: {duplicate_count}")
print(f"Pairs identified as Contradictory: {contradicting_count}")
print(f"Number of unique scenarios after deduplication: {scenarios_after_cleanup}")
print(f"------------------------------------")
# Out:
#                                                                                                                 Step 1  \
# 0                                                                       Given: A user is not authenticated with Scribl
# 1                                                                       Given: A user is not authenticated with Scribl
# 2                                                                       Given: A user is not authenticated with Scribl
# 3                                                                       Given: A user is not authenticated with Scribl
# 4                                                                       Given: A user is not authenticated with Scribl
# ...                                                                                                                ...
# 2456431  Then: A complete audit trail of who approved/rejected, when, and any associated comments should be maintained
# 2456432  Then: A complete audit trail of who approved/rejected, when, and any associated comments should be maintained
# 2456433                                                   Given: An approval workflow involves dynamic decision-making
# 2456434                                                   Given: An approval workflow involves dynamic decision-making
# 2456435                                                                     When: Conditional approvals are configured
#
#                                                                                                                                                        Step 2  \
# 0                                                                                                       When: The user attempts to sign in via LinkedIn OAuth
# 1        Then: The system retrieves the user's LinkedIn profile data (name, title, connections, profile picture), and the system creates a Scribl user record
# 2                                                                                                Given: A new user has successfully authenticated with Scribl
# 3                               When: The user starts the multi-step onboarding flow and provides goals, brand voice, posting frequency, and niche selections
# 4                                                         Then: The system saves the user's progress automatically, and the user's preferences are configured
# ...                                                                                                                                                       ...
# 2456431                                                                                                            When: Conditional approvals are configured
# 2456432    Then: The workflow should adjust its path or require additional approvals based on specific criteria within the request (e.g., amount, department)
# 2456433                                                                                                            When: Conditional approvals are configured
# 2456434    Then: The workflow should adjust its path or require additional approvals based on specific criteria within the request (e.g., amount, department)
# 2456435    Then: The workflow should adjust its path or require additional approvals based on specific criteria within the request (e.g., amount, department)
#
#          Similarity      NLI Label  Confidence         Decision
# 0            0.3181        NEUTRAL      100.00    ❌ Not Similar
# 1            0.5064        NEUTRAL      100.00    ❌ Not Similar
# 2            0.8241  CONTRADICTION       99.25  ❌ Contradictory
# 3            0.0841        NEUTRAL      100.00    ❌ Not Similar
# 4            0.0481        NEUTRAL      100.00    ❌ Not Similar
# ...             ...            ...         ...              ...
# 2456431      0.3769        NEUTRAL      100.00    ❌ Not Similar
# 2456432      0.4269        NEUTRAL      100.00    ❌ Not Similar
# 2456433      0.4849        NEUTRAL      100.00    ❌ Not Similar
# 2456434      0.5097        NEUTRAL      100.00    ❌ Not Similar
# 2456435      0.4045        NEUTRAL      100.00    ❌ Not Similar
#
# [2456436 rows x 6 columns]
# --- Summary of BDD Step Analysis ---
# Total individual steps analyzed: 2217
# Pairs identified as Likely Duplicates: 174
# Pairs identified as Contradictory: 46
# Number of unique scenarios after deduplication: 740
# ------------------------------------

# %%
# ------------------------------------------------------
# 6. Save to CSV
# ------------------------------------------------------
output_path = "macro_hard_full_sentence_comparison_results.csv"
df_results.to_csv(output_path, index=False)
print(f"\n✅ Results saved to '{output_path}'")
# Out:
# ✅ Results saved to 'macro_hard_full_sentence_comparison_results.csv'

# %% [markdown]
# # ------------- NEW CODE ENDS HERE ⬆️------------------------------

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

#=========== SAVE DUPLICATES TO A CSV for later inspection ============
# COSINE SIMILARITY
def remove_duplicates(features, threshold=0.9, show_duplicates=True):
    """Remove semantically similar BDD scenarios using cosine similarity and show duplicates."""

    # model = SentenceTransformer('all-MiniLM-L6-v2')
    model = SentenceTransformer('intfloat/e5-large-v2')

    texts = [
        f"Given {f.get('given', '')} When {f.get('when', '')} Then {f.get('then', '')}"
        for f in features
    ]

    # Extract When and Then texts separately for contrast check
    whens = [f.get('when', '') for f in features]
    thens = [f.get('then', '') for f in features]


    embeddings = model.encode(texts)
    sim_matrix = cosine_similarity(embeddings)

    seen = set()
    unique_indices = []
    duplicates = []  # store tuples of (original_idx, duplicate_idx, similarity)

    # Define contradictory keyword pairs
    contrast_pairs = [
        ("success", "error"), ("approve", "reject"),
        ("completed", "failed"), ("allow", "deny"),
        ("green", "red"), ("enabled", "disabled"),
        ("true", "false")
    ]

    def has_contrast(text1, text2):
        t1, t2 = text1.lower(), text2.lower()
        for a, b in contrast_pairs:
            if (a in t1 and b in t2) or (b in t1 and a in t2):
                return True
        return False


    for i in range(len(features)):
        if i in seen:
            continue
        for j in range(i + 1, len(features)):
            # Check for both similarity and lack of contrast
            if sim_matrix[i, j] > threshold and not has_contrast(
                f"{whens[i]} {thens[i]}", f"{whens[j]} {thens[j]}"
            ):
                seen.add(j)
                duplicates.append((i, j, sim_matrix[i, j]))
        unique_indices.append(i)

    removed_count = len(features) - len(unique_indices)
    print(f"\n🧹 Before cleanup: {len(features)} scenarios\n")
    print(f"❌🗑️ Removed {removed_count} DUPLICATE SCENARIOS.\n")
    print(f"✅ After cleanup: {len(unique_indices)} scenarios\n")

    if show_duplicates and duplicates:
        print("🔍 Duplicate scenario pairs (showing top 10 by similarity):\n")
        # Sort duplicates by similarity descending
        duplicates = sorted(duplicates, key=lambda x: x[2], reverse=True)

        for i, (a, b, score) in enumerate(duplicates[:10]):
            print(f"\n🧩 Similarity: {score:.3f}")
            print(f"🅰️ Scenario A: {texts[a][:300]}")
            print(f"🅱️ Scenario B: {texts[b][:300]}")
            print("-" * 80)

    # Optional: save to CSV for later inspection
    if show_duplicates and duplicates:
        dup_data = [
            {"original_index": a, "duplicate_index": b, "similarity": score,
             "scenario_A": texts[a], "scenario_B": texts[b]}
            for a, b, score in duplicates
        ]
        pd.DataFrame(dup_data).to_csv("duplicates_report.csv", index=False, encoding="utf-8")
        print("\n📁 Detailed duplicate report saved → duplicates_report.csv")

    return [features[i] for i in unique_indices]

# %%
# 🔍 Remove near-duplicate scenarios

print(f"🧹 Before cleanup: {len(bdd_json['features'])} scenarios")

# --- Save before deduplication ---
raw_output_path = Path("bdd_output_gemini_raw.json")
with open(raw_output_path, "w", encoding="utf-8") as f:
    json.dump(bdd_json, f, indent=2, ensure_ascii=False)
print(f"\n📁 Saved original (before deduplication): {raw_output_path.resolve()}")




bdd_json["features"] = remove_duplicates(bdd_json["features"], threshold=0.9)





print(f"\n\n✅ After cleanup: {len(bdd_json['features'])} scenarios")

deduped_output_path = Path("bdd_output_gemini_duplicates_removed.json")
with open(deduped_output_path, "w", encoding="utf-8") as f:
    json.dump(bdd_json, f, indent=2, ensure_ascii=False)
print(f"\n📁 Saved cleaned (after deduplication): {deduped_output_path.resolve()}")

print(f"\n✅ BDD JSON created: {deduped_output_path.resolve()}")
# Out:
# 🧹 Before cleanup: 1375 scenarios
#
# 📁 Saved original (before deduplication): /content/bdd_output_gemini_raw.json
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]
# 🧹 Before cleanup: 1375 scenarios
#
# ❌🗑️ Removed 635 DUPLICATE SCENARIOS.
#
# ✅ After cleanup: 740 scenarios
#
# 🔍 Duplicate scenario pairs (showing top 10 by similarity):
#
#
# 🧩 Similarity: 0.995
# 🅰️ Scenario A: Given An existing 'User' and a specified amount of 'creditsTotal'. When A request is made to allocate AI credits to the 'userId'. Then An 'AiCreditAllocation' record should be created for the user, setting 'creditsTotal' and 'creditsRemaining' to the allocated amount, with 'allocatedAt' timestamped.
# 🅱️ Scenario B: Given An existing 'Team' and a specified amount of 'creditsTotal'. When A request is made to allocate AI credits to the 'teamId'. Then An 'AiCreditAllocation' record should be created for the team, setting 'creditsTotal' and 'creditsRemaining' to the allocated amount, with 'allocatedAt' timestamped.
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.984
# 🅰️ Scenario A: Given A user has authorized the application on LinkedIn and is new to the system When The LinkedIn OAuth callback endpoint is invoked with the authorization 'code' Then The system exchanges the code, creates a new User and LinkedInProfile, and returns a JWT/session along with a User summary
# 🅱️ Scenario B: Given An existing user has authorized the application on LinkedIn When The LinkedIn OAuth callback endpoint is invoked with the authorization 'code' Then The system exchanges the code, merges the LinkedInProfile with the existing User, and returns a JWT/session along with a User summary
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.984
# 🅰️ Scenario A: Given A user wants to manage their personal and brand settings. When The user accesses their Profile & Settings. Then The user can configure brand voice, general preferences, and initiate GDPR data export or deletion requests.
# 🅱️ Scenario B: Given a user wants to manage their account When the user accesses their Profile & Settings Then they can configure brand voice, personal preferences, and initiate GDPR data export or deletion requests
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.978
# 🅰️ Scenario A: Given A user is in the same team and has OrgPageAccess.role = PUBLISHER, Admin, or Approver, a valid OrganizationLinkedInAccount token, and the content does not require approval or the user is an Approver. When The user sends a POST request to /api/publish/linkedin/org with valid contentId, orgAccou
# 🅱️ Scenario B: Given A user is in the same team and has OrgPageAccess.role = PUBLISHER, a valid OrganizationLinkedInAccount token, and the workspace requires approval but the user is not an Approver. When The user sends a POST request to /api/publish/linkedin/org with valid contentId, orgAccountId, pageId, schedul
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.974
# 🅰️ Scenario A: Given an ImportJob exists with a 'PENDING' status When the import system begins processing the job Then the ImportJob's status is updated to 'PROCESSING'.
# 🅱️ Scenario B: Given an ExportJob exists with a 'PENDING' status When the export system begins processing the job Then the ExportJob's status is updated to 'PROCESSING'.
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.974
# 🅰️ Scenario A: Given An existing ContentItem. When The content item is requested to be deleted. Then The deletedAt field of the ContentItem should be populated with the current timestamp, indicating a soft deletion.
# 🅱️ Scenario B: Given An existing ContentItem. When The ContentItem is marked for deletion. Then The 'deleted_at' field of the ContentItem should be populated with a timestamp, indicating soft deletion.
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.973
# 🅰️ Scenario A: Given a team with multiple members When team members are queried by team ID Then all TeamMember records associated with that team ID are returned
# 🅱️ Scenario B: Given a user is a member of multiple teams When team memberships are queried by user ID Then all TeamMember records associated with that user ID are returned
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.972
# 🅰️ Scenario A: Given A user is viewing a LinkedIn post in the Engage Feed When The user clicks the 'Like' button within Scribl Then The post is liked on LinkedIn via the API, and the like count is updated in Scribl
# 🅱️ Scenario B: Given A user is viewing a LinkedIn post in the Engage Feed When The user enters a comment and clicks 'Comment' within Scribl Then The comment is posted to LinkedIn via the API, and the comment count is updated in Scribl
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.970
# 🅰️ Scenario A: Given A user wants to connect Scribl with other business tools. When The user configures integrations with platforms like Slack, CRM, email, calendar, Salesforce, or HubSpot. Then Data and workflows are seamlessly synchronized between Scribl and the integrated external services.
# 🅱️ Scenario B: Given a user wants to connect Scribl with other tools When the user configures integrations with platforms like Slack, CRM, email, calendar, Salesforce, or HubSpot Then Scribl can seamlessly exchange data and workflows with these external systems
# --------------------------------------------------------------------------------
#
# 🧩 Similarity: 0.970
# 🅰️ Scenario A: Given A user is authenticated and a valid 'ContentCreateRequest' is provided When A POST request is made to '/contents' to create a new content item Then A 201 status is returned with the created ContentItem
# 🅱️ Scenario B: Given An authenticated user wants to create a new content item. When The user provides valid content details (at least 'type' and 'ownerId') in a ContentCreateRequest to POST /contents. Then The system successfully creates and returns the new ContentItem with a 201 status.
# --------------------------------------------------------------------------------
#
# 📁 Detailed duplicate report saved → duplicates_report.csv
#
#
# ✅ After cleanup: 740 scenarios
#
# 📁 Saved cleaned (after deduplication): /content/bdd_output_gemini_duplicates_removed.json
#
# ✅ BDD JSON created: /content/bdd_output_gemini_duplicates_removed.json

# %%
# # Save Final JSON
# output_path = Path("bdd_output_gemini_duplicates_removed.json")
# with open(output_path, "w", encoding="utf-8") as f:
#     json.dump(bdd_json, f, indent=2, ensure_ascii=False) # ensure_asci=False ; don’t convert non-English characters into escape codes. Keep them readable as they are.

# print(f"\n✅ BDD JSON created: {output_path.resolve()}")

# %% [markdown]
# # Outputting the Results

# %%
import json
from google.colab import files

# Suppose your file name is "bdd_output_gemini.json"
file_name = "bdd_output_gemini.json"

# Read & parse JSON
with open(file_name, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Pretty print the JSON (indentation)
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "features": [
#     {
#       "given": "A user wants to access Scribl",
#       "when": "The user authenticates through LinkedIn OAuth",
#       "then": "The system retrieves their LinkedIn profile data (name, title, connections, profile picture) and creates a Scribl user record"
#     },
#     {
#       "given": "A new user has successfully authenticated with Scribl",
#       "when": "The user proceeds through the guided, multi-step onboarding process",
#       "then": "The system collects user goals, brand voice preferences, posting frequency, and niche selections, and auto-saves their progress"
#     },
#     {
#       "given": "A Team Admin is setting up Scribl for their team",
#       "when": "The Admin selects the number of seats and a subscription plan",
#       "then": "A real-time calculator displays pricing and features, and the system processes payment via Stripe before provisioning access"
#     },
#     {
#       "given": "A user is in the content creation interface",
#       "when": "The user inputs an idea or prompt into the AI Assistant",
#       "then": "The AI generates multiple content variations (posts, articles, captions) aligned with the user's brand voice, allowing for iterative refinement"
#     },
#     {
#       "given": "A user is creating content",
#       "when": "The user interacts with the Chat Canvas",
#       "then": "The system provides a combined chat panel for AI interaction and a visual editor for content refinement"
#     },
#     {
#       "given": "A user is editing a post",
#       "when": "The user drags and drops a text block, image, or design element onto the editor",
#       "then": "The element is positioned within the post"
#     },
#     {
#       "given": "A user is editing a post",
#       "when": "The user applies formatting (e.g., bold, italics) to selected text",
#       "then": "The text's formatting is updated in the editor"
#     },
#     {
#       "given": "A user is editing a post",
#       "when": "The user selects the 'preview' option",
#       "then": "The system displays the post as it would appear on LinkedIn"
#     },
#     {
#       "given": "A user wants to create new content",
#       "when": "The user selects a pre-designed template categorized by use case or industry",
#       "then": "The content editor is pre-filled with the structure and elements of the chosen template"
#     },
#     {
#       "given": "A user has designed a custom content structure",
#       "when": "The user saves this structure as a new custom template",
#       "then": "The custom template is available for team-wide reuse"
#     },
#     {
#       "given": "A user wants to create a multi-slide carousel",
#       "when": "The user uses the Carousel Creator",
#       "then": "The user can add and arrange multiple slides for a carousel post"
#     },
#     {
#       "given": "A user is creating a carousel using the Carousel Creator",
#       "when": "The user selects a storytelling, step-by-step guide, or product showcase template",
#       "then": "The carousel is pre-structured according to the selected template"
#     },
#     {
#       "given": "A user is creating a carousel",
#       "when": "The user views a live preview in the Carousel Creator",
#       "then": "The preview accurately reflects how the carousel will appear on LinkedIn, and the system flags any non-compliant elements"
#     },
#     {
#       "given": "A user navigates to the Content Library",
#       "when": "The Content Library loads",
#       "then": "All content items associated with the user/team are displayed in a centralized repository"
#     },
#     {
#       "given": "A user is viewing the Content Library",
#       "when": "The user applies filters for status (draft, scheduled, published), content type, or tags",
#       "then": "The Content Library displays only the content items matching the applied filters"
#     },
#     {
#       "given": "A user has selected multiple content items in the Content Library",
#       "when": "The user initiates a bulk action (e.g., delete, duplicate, export)",
#       "then": "The selected action is applied to all chosen content items"
#     },
#     {
#       "given": "An editor has finished drafting content",
#       "when": "The editor submits the content for review",
#       "then": "The content's status changes to 'In Review' and is sent to approvers"
#     },
#     {
#       "given": "An approver is reviewing content",
#       "when": "The approver adds comments, requests changes, or approves the content",
#       "then": "The content's status is updated, and the editor is notified of the action"
#     },
#     {
#       "given": "Content has been approved by an approver",
#       "when": "The approval process is completed",
#       "then": "The content becomes available for scheduling"
#     },
#     {
#       "given": "A user is editing content",
#       "when": "The user saves a draft of the content",
#       "then": "A new version of the content is created and tracked"
#     },
#     {
#       "given": "A user is viewing the version history of content",
#       "when": "The user selects a prior version to restore or compare",
#       "then": "The content reverts to the selected prior version, or the user can view the differences"
#     },
#     {
#       "given": "A user wants to schedule content",
#       "when": "The user accesses the visual calendar",
#       "then": "The user can assign content to specific future dates on the calendar"
#     },
#     {
#       "given": "Content is scheduled on the visual calendar",
#       "when": "The user drags and drops a scheduled content item to a new date",
#       "then": "The content's scheduled date is updated"
#     },
#     {
#       "given": "A user is scheduling content",
#       "when": "The user configures a post as recurring or adjusts the time zone for scheduling",
#       "then": "The system schedules the post according to the recurrence settings or specified time zone"
#     },
#     {
#       "given": "Content is scheduled for a specific time",
#       "when": "The scheduled time arrives",
#       "then": "The system automatically publishes the content to LinkedIn via API"
#     },
#     {
#       "given": "Content is scheduled for publication",
#       "when": "The initial attempt to publish via LinkedIn API fails",
#       "then": "The system retries the publication and sends an alert if the error persists"
#     },
#     {
#       "given": "Content has been published or failed to publish",
#       "when": "The publishing status is determined",
#       "then": "The user receives an in-app and email notification confirming success or alerting of failure"
#     },
#     {
#       "given": "A user accesses the Engage Feed",
#       "when": "The Engage Feed loads",
#       "then": "The feed displays relevant LinkedIn posts from the user's network and industry"
#     },
#     {
#       "given": "A user is viewing the Engage Feed",
#       "when": "The Engage Feed is loaded or refreshed",
#       "then": "Posts identified as most suitable for engagement are displayed with higher priority"
#     },
#     {
#       "given": "A user is viewing a LinkedIn post in the Engage Feed",
#       "when": "The user clicks a 'Like,' 'Comment,' or 'Share' button",
#       "then": "The action is executed on LinkedIn via API without the user leaving Scribl"
#     },
#     {
#       "given": "A user is about to comment on a LinkedIn post in Scribl",
#       "when": "The user requests AI suggestions for a comment or reply",
#       "then": "Scribl provides suggested comments or replies aligned with professional tone and brand voice"
#     },
#     {
#       "given": "AI suggestions for comments are displayed",
#       "when": "The user selects a suggestion or edits it",
#       "then": "The chosen or edited text is prepared for posting as a comment"
#     },
#     {
#       "given": "A user is viewing networking metrics",
#       "when": "The networking metrics dashboard is loaded",
#       "then": "The system displays engagement levels with connections and highlights opportunities for relationship-building"
#     },
#     {
#       "given": "A user accesses the Discovery/Opportunities section",
#       "when": "The Trending Topics feature is displayed",
#       "then": "The system presents trending themes relevant to the user's niche, based on AI analysis of LinkedIn data"
#     },
#     {
#       "given": "A user accesses the Competitor Analysis feature",
#       "when": "The competitor analysis report is generated",
#       "then": "The system displays the user's content performance benchmarked against selected competitors or similar accounts"
#     },
#     {
#       "given": "A user views the Gap Analysis report",
#       "when": "The Gap Analysis is performed",
#       "then": "The system identifies content areas where competitors are active but the user is not, and suggests new content directions"
#     },
#     {
#       "given": "The system suggests a new content topic",
#       "when": "The user views the suggested topic",
#       "then": "The system displays a forecasted engagement level for that topic based on AI prediction"
#     },
#     {
#       "given": "A user accesses the Analytics Dashboard",
#       "when": "The dashboard loads",
#       "then": "Visual reports displaying impressions, clicks, engagement rates, and follower growth are shown"
#     },
#     {
#       "given": "A user is viewing the Analytics Dashboard",
#       "when": "The user applies filters for time range, content type, or team member",
#       "then": "The analytics reports are updated to reflect the data for the applied filters"
#     },
#     {
#       "given": "A user views AI Insights",
#       "when": "The AI Insights are generated",
#       "then": "Scribl provides tailored recommendations based on past performance, such as best posting times or high-engagement content types"
#     },
#     {
#       "given": "A user is viewing analytics reports",
#       "when": "The user selects an export option (CSV or PDF)",
#       "then": "The analytics data is exported in the chosen format"
#     },
#     {
#       "given": "An admin is in the Team Management section",
#       "when": "The admin invites a new member via email, assigns a role, or modifies permissions",
#       "then": "The new member is invited, or the role/permissions of an existing member are updated"
#     },
#     {
#       "given": "An admin is in the Team Management section",
#       "when": "The admin views the team roster",
#       "then": "The system displays the current seat usage"
#     },
#     {
#       "given": "An enterprise admin has an enterprise account",
#       "when": "The admin creates a new team workspace",
#       "then": "A new workspace with separate content, analytics, and templates is created"
#     },
#     {
#       "given": "An action (created, edited, approved, published) is performed in Scribl",
#       "when": "The action is completed",
#       "then": "The system records the action, timestamp, and the performing actor in the audit log"
#     },
#     {
#       "given": "An admin accesses the Audit & Activity Logs",
#       "when": "The admin reviews the logs",
#       "then": "The admin can view a chronological record of key actions for compliance and accountability"
#     },
#     {
#       "given": "A user navigates to Billing Management",
#       "when": "The user accesses the billing portal",
#       "then": "The user can view subscription status, download invoices, and update payment methods"
#     },
#     {
#       "given": "A user wants to change their subscription plan",
#       "when": "The user upgrades or downgrades their subscription",
#       "then": "The system adjusts the billing with prorated charges"
#     },
#     {
#       "given": "a user has a pending approval for content",
#       "when": "they log into the application",
#       "then": "an in-app alert for the pending approval should be displayed"
#     },
#     {
#       "given": "a user successfully publishes content",
#       "when": "the publishing process completes",
#       "then": "an in-app alert confirming the publishing should be displayed"
#     },
#     {
#       "given": "a system error occurs during an operation",
#       "when": "the user is interacting with the application",
#       "then": "an in-app alert detailing the error should be displayed"
#     },
#     {
#       "given": "a user's payment fails",
#       "when": "the payment processing system attempts to charge the user",
#       "then": "the user should receive an email alert regarding the failed payment"
#     },
#     {
#       "given": "a critical error occurs during content publishing",
#       "when": "the publishing attempt fails",
#       "then": "the user should receive an email alert regarding the publishing error"
#     },
#     {
#       "given": "a team has Slack/Teams integration enabled",
#       "when": "a relevant team event (e.g., content approval, new comment) occurs",
#       "then": "a real-time notification should be sent to the configured Slack/Teams channel"
#     },
#     {
#       "given": "a user is viewing their profile",
#       "when": "they edit their name and save the changes",
#       "then": "their profile should display the updated name"
#     },
#     {
#       "given": "a user is viewing their profile",
#       "when": "they edit their job title and save the changes",
#       "then": "their profile should display the updated title"
#     },
#     {
#       "given": "a user is viewing their profile",
#       "when": "they upload a new profile picture and save the changes",
#       "then": "their profile should display the new profile picture"
#     },
#     {
#       "given": "a user is viewing their profile settings",
#       "when": "they update their brand voice preferences and save the changes",
#       "then": "their content creation tools should reflect the updated brand voice preferences"
#     },
#     {
#       "given": "a user is in their preferences settings",
#       "when": "they adjust the notification frequency and save the changes",
#       "then": "the system should send notifications according to the new frequency"
#     },
#     {
#       "given": "a user is in their preferences settings",
#       "when": "they modify their privacy controls and save the changes",
#       "then": "their data visibility and sharing should adhere to the updated privacy controls"
#     },
#     {
#       "given": "a user is in their preferences settings",
#       "when": "they enable dark mode for the UI and save the changes",
#       "then": "the application's user interface should switch to dark mode"
#     },
#     {
#       "given": "a user requests an export of their data",
#       "when": "they initiate the data export process",
#       "then": "the system should process and provide their data in an exportable format (e.g., CSV/JSON)"
#     },
#     {
#       "given": "a user requests account deletion in accordance with GDPR",
#       "when": "they initiate the account deletion process",
#       "then": "the system should permanently delete their account and associated data as per GDPR guidelines"
#     },
#     {
#       "given": "a user is creating content and needs an image",
#       "when": "they use the image search feature and select an image from Unsplash/Pexels",
#       "then": "the selected stock image should be inserted directly into their post"
#     },
#     {
#       "given": "a user inserts a stock image from the integrated library",
#       "when": "the image is added to the content",
#       "then": "the system should automatically add the required attribution for the image"
#     },
#     {
#       "given": "a user frequently uses certain stock images",
#       "when": "they access those images again",
#       "then": "the system should retrieve the images from a local cache to improve loading performance"
#     },
#     {
#       "given": "a user is on the platform",
#       "when": "they enter a query into the unified search bar",
#       "then": "the search results should include relevant content, templates, analytics data, and opportunities"
#     },
#     {
#       "given": "a user has performed a global search",
#       "when": "they apply a filter for specific tags",
#       "then": "the search results should be narrowed down to only show items matching the selected tags"
#     },
#     {
#       "given": "a user has performed a global search",
#       "when": "they apply a filter for a specific status (e.g., Draft, Published, Pending Approval)",
#       "then": "the search results should be narrowed down to only show items with the selected status"
#     },
#     {
#       "given": "a user has performed a global search",
#       "when": "they apply a filter for specific user roles",
#       "then": "the search results should be narrowed down to only show items relevant to the selected roles"
#     },
#     {
#       "given": "a user has performed a global search",
#       "when": "they apply a filter for a specific content type (e.g., Post, Article, Video)",
#       "then": "the search results should be narrowed down to only show items of the selected content type"
#     },
#     {
#       "given": "a user accesses the web application on a mobile browser",
#       "when": "they navigate through different sections",
#       "then": "the application's layout should be optimized and fully responsive for the mobile screen"
#     },
#     {
#       "given": "a user is on a mobile device",
#       "when": "they want to quickly draft new content",
#       "then": "they should be able to use a 'Quick Create' feature designed for fast drafting on small screens"
#     },
#     {
#       "given": "a user is on a mobile device",
#       "when": "they need to approve or reject content",
#       "then": "they should be able to complete the approvals workflow seamlessly on their small screen"
#     },
#     {
#       "given": "a user is on a mobile device",
#       "when": "they need to schedule content for publishing",
#       "then": "they should be able to complete the scheduling workflow efficiently on their small screen"
#     },
#     {
#       "given": "a user wants to back up their content",
#       "when": "they select to export their posts",
#       "then": "the system should allow them to export posts in CSV or JSON format"
#     },
#     {
#       "given": "a user wants to analyze their performance data externally",
#       "when": "they select to export their analytics",
#       "then": "the system should allow them to export analytics data in CSV or JSON format"
#     },
#     {
#       "given": "a user wants to transfer their templates",
#       "when": "they select to export their templates",
#       "then": "the system should allow them to export templates in CSV or JSON format"
#     },
#     {
#       "given": "an Enterprise user is setting up their account",
#       "when": "they upload a bulk file of templates",
#       "then": "the system should process and import all templates, populating their library for faster setup"
#     },
#     {
#       "given": "an Enterprise user is adding team members",
#       "when": "they upload a bulk file of team member lists",
#       "then": "the system should process and import all team members, granting them access for faster setup"
#     },
#     {
#       "given": "a user needs assistance",
#       "when": "they access the Help Center integration within the app",
#       "then": "they should be able to find relevant FAQs and support documentation"
#     },
#     {
#       "given": "a new user logs in for the first time",
#       "when": "they start exploring the application",
#       "then": "an interactive onboarding tour should automatically begin, guiding them through each module"
#     },
#     {
#       "given": "a user encounters an issue",
#       "when": "they utilize the in-app support ticket feature",
#       "then": "they should be able to report the issue directly through integration with helpdesk platforms like Zendesk or Intercom"
#     },
#     {
#       "given": "a user wants to access Scribl",
#       "when": "they attempt to log in using LinkedIn OAuth",
#       "then": "they should be authenticated successfully."
#     },
#     {
#       "given": "a new user has successfully authenticated",
#       "when": "they complete the guided onboarding process by defining their goals, brand voice, frequency, and niches",
#       "then": "their preferences should be saved and applied to their account."
#     },
#     {
#       "given": "a user is onboarding and needs to select a plan",
#       "when": "they choose a seat and complete the subscription via Stripe",
#       "then": "their subscription should be activated and billing initiated."
#     },
#     {
#       "given": "a user wants to create content using the AI assistant",
#       "when": "they provide a prompt",
#       "then": "the AI assistant should generate multiple content variations."
#     },
#     {
#       "given": "a user is creating content",
#       "when": "they use the chat and canvas editor to add text and visuals",
#       "then": "they should be able to preview the content in real-time."
#     },
#     {
#       "given": "a user wants to create content quickly",
#       "when": "they select a template from an industry category (e.g., post, article, carousel)",
#       "then": "the editor should load the pre-designed template."
#     },
#     {
#       "given": "a user is building a carousel",
#       "when": "they add multiple slides and preview them",
#       "then": "the builder should ensure the carousel complies with publishing standards."
#     },
#     {
#       "given": "a user wants to access more templates",
#       "when": "they browse the Template Marketplace",
#       "then": "they should be able to find and utilize community or premium templates."
#     },
#     {
#       "given": "a user has created a valuable template",
#       "when": "they share it on the Template Marketplace",
#       "then": "it should be available for other users, potentially for monetization."
#     },
#     {
#       "given": "a user has created multiple content pieces",
#       "when": "they access the content library",
#       "then": "all their content should be centrally stored and easily discoverable."
#     },
#     {
#       "given": "content requires approval by an approver",
#       "when": "an editor submits content for review, and the approver either approves or rejects it",
#       "then": "the content status should be updated accordingly and the workflow progressed."
#     },
#     {
#       "given": "content has been edited multiple times",
#       "when": "a user views its history",
#       "then": "they should be able to see previous versions and roll back to an earlier version."
#     },
#     {
#       "given": "a user wants to schedule content",
#       "when": "they use the calendar to drag-and-drop a post, set it as recurring, and specify a timezone",
#       "then": "the content should be scheduled correctly."
#     },
#     {
#       "given": "content is scheduled for publishing",
#       "when": "the scheduled time arrives",
#       "then": "the system should attempt to publish the content automatically, applying retry logic if needed, and generating alerts on failures."
#     },
#     {
#       "given": "content has been published",
#       "when": "the publishing process completes (successfully or with failure)",
#       "then": "the user should receive a notification confirming the outcome."
#     },
#     {
#       "given": "a user wants to engage with their network",
#       "when": "they view the engagement feed",
#       "then": "they should see prioritized posts relevant for interaction."
#     },
#     {
#       "given": "a user is viewing a post in the engagement feed",
#       "when": "they click a one-click action (like, comment, or share)",
#       "then": "their interaction should be registered on the post."
#     },
#     {
#       "given": "a user is about to comment on a post",
#       "when": "they initiate a comment",
#       "then": "the AI should provide relevant comment or reply suggestions."
#     },
#     {
#       "given": "a user wants to understand their networking impact",
#       "when": "they view networking metrics",
#       "then": "they should see tracked engagement of their connections."
#     },
#     {
#       "given": "a user is looking for content ideas",
#       "when": "they access the Discovery section",
#       "then": "they should see trending topics identified by AI and LinkedIn signals."
#     },
#     {
#       "given": "a user wants to analyze their market position",
#       "when": "they perform a competitor and gap analysis",
#       "then": "they should receive insights into their competitive landscape."
#     },
#     {
#       "given": "a user has drafted content",
#       "when": "they request a predicted performance",
#       "then": "the AI should provide a forecast of its potential reach and engagement before publishing."
#     },
#     {
#       "given": "a user wants to review their performance",
#       "when": "they access the analytics dashboards",
#       "then": "they should see metrics like impressions, clicks, engagement, and follower growth."
#     },
#     {
#       "given": "a user wants optimized strategies",
#       "when": "they review AI insights",
#       "then": "they should receive recommendations for best posting times and identification of high-performing content."
#     },
#     {
#       "given": "a user wants to share or analyze data externally",
#       "when": "they choose to export analytics data",
#       "then": "they should be able to export it in CSV, PDF, or JSON formats."
#     },
#     {
#       "given": "an admin is managing a team",
#       "when": "they assign roles (admin, editor, approver, analyst) to team members",
#       "then": "each member should have the appropriate access levels."
#     },
#     {
#       "given": "an enterprise user manages multiple entities",
#       "when": "they set up multiple workspaces (e.g., by region, team, or brand)",
#       "then": "each workspace should operate independently with its own configurations."
#     },
#     {
#       "given": "an admin wants to monitor team activity",
#       "when": "they review the audit and activity logs",
#       "then": "they should see a record of all significant actions taken within the workspace."
#     },
#     {
#       "given": "a user belongs to a specific role",
#       "when": "they attempt an action",
#       "then": "their access should be restricted or allowed based on their role and compliance requirements."
#     },
#     {
#       "given": "an admin is configuring user permissions",
#       "when": "they set granular controls (e.g., allow only 'analytics-only' access)",
#       "then": "the user's capabilities should strictly adhere to those controls."
#     },
#     {
#       "given": "content requires multi-step approval",
#       "when": "it moves through the approval hierarchy",
#       "then": "it should only be publishable after all required reviewers have approved it."
#     },
#     {
#       "given": "content or data reaches its retention period",
#       "when": "the system applies retention policies",
#       "then": "the data should be archived or deleted according to the defined rules."
#     },
#     {
#       "given": "a user operates in a specific region (e.g., EU)",
#       "when": "data is stored and processed",
#       "then": "it should comply with region-based data segregation rules."
#     },
#     {
#       "given": "a user wants to subscribe",
#       "when": "they select a tiered plan (Normal, Pro, or Enterprise)",
#       "then": "their account should be provisioned with the features of that tier."
#     },
#     {
#       "given": "a user is managing their subscription",
#       "when": "they access the billing dashboard",
#       "then": "they should see their subscription status, invoices, and payment methods."
#     },
#     {
#       "given": "a user wants to change their plan",
#       "when": "they upgrade or downgrade their subscription",
#       "then": "the billing should be prorated correctly for the current billing cycle."
#     },
#     {
#       "given": "a user is on a specific subscription tier",
#       "when": "they use AI features",
#       "then": "their usage should be deducted from their allocated AI credits according to their tier."
#     },
#     {
#       "given": "a user creates different types of content with AI",
#       "when": "AI content is generated",
#       "then": "credits should be calculated and deducted based on the content type (e.g., post, article, carousel)."
#     },
#     {
#       "given": "an admin wants to monitor AI credit consumption",
#       "when": "they view the usage tracking dashboard",
#       "then": "they should see AI credit usage per user or team."
#     },
#     {
#       "given": "a user is running low on AI credits",
#       "when": "their credit balance reaches a threshold",
#       "then": "they should receive alerts and have options to purchase extra credit packs or enable auto top-ups."
#     },
#     {
#       "given": "an admin manages AI credits for their team",
#       "when": "they use admin controls",
#       "then": "they should be able to allocate specific credit amounts to individual team members."
#     },
#     {
#       "given": "a significant event occurs (e.g., content approved, publishing failed)",
#       "when": "a user is affected",
#       "then": "they should receive notifications and alerts via in-app, email, or integrated channels like Slack/Teams."
#     },
#     {
#       "given": "a user wants to manage their account",
#       "when": "they access their profile and settings",
#       "then": "they should be able to update their brand voice, preferences, and exercise GDPR rights (export/deletion)."
#     },
#     {
#       "given": "a user is creating content and needs an image",
#       "when": "they search the stock image library",
#       "then": "they should find images from Unsplash/Pexels with proper attribution and benefit from caching."
#     },
#     {
#       "given": "a user is looking for specific content or data",
#       "when": "they use the global search bar or apply advanced filters",
#       "then": "they should be able to quickly find relevant information."
#     },
#     {
#       "given": "a user is accessing Scribl on a mobile device",
#       "when": "they use the responsive PWA",
#       "then": "they should be able to quickly create, approve, and publish content."
#     },
#     {
#       "given": "an enterprise user needs to manage data in bulk",
#       "when": "they use the data import/export functionality",
#       "then": "they should be able to import or export data in CSV/JSON formats."
#     },
#     {
#       "given": "a user needs assistance",
#       "when": "they access the support features",
#       "then": "they should find a help center, onboarding tours, and the ability to submit support tickets."
#     },
#     {
#       "given": "a user prefers a specific language",
#       "when": "they select their preferred language",
#       "then": "the UI and AI content generation should be presented in that language."
#     },
#     {
#       "given": "a user wants to connect Scribl with other tools",
#       "when": "they manage integrations",
#       "then": "they should be able to set up connections with Slack, CRM, email, calendar, and specific platforms like Salesforce/HubSpot."
#     },
#     {
#       "given": "a developer wants to extend Scribl functionality",
#       "when": "they use the API and developer access features",
#       "then": "they should be able to interact with Scribl via REST/GraphQL APIs, webhooks, API keys, and adhere to rate limits."
#     },
#     {
#       "given": "A user has authored a new content item.",
#       "when": "The content item is submitted for content compliance checks.",
#       "then": "The system identifies any plagiarized sections and flags the content for review."
#     },
#     {
#       "given": "A user has authored a new content item.",
#       "when": "The content item is submitted for content compliance checks.",
#       "then": "The system identifies any content that violates AI safety guidelines and flags it for review."
#     },
#     {
#       "given": "A user possesses a specific role within a workspace.",
#       "when": "The user attempts to perform an action (e.g., edit content, publish content) that requires certain permissions.",
#       "then": "The system grants or denies the action based on the permissions associated with the user's role."
#     },
#     {
#       "given": "A user performs a significant action within the system (e.g., changes a role, publishes a post).",
#       "when": "The action is successfully completed.",
#       "then": "An entry detailing the actor, action, target, and timestamp is immutably recorded in the audit logs."
#     },
#     {
#       "given": "Sensitive user or content data is stored in the database.",
#       "when": "The data is persisted to storage.",
#       "then": "The data is encrypted at rest to prevent unauthorized access."
#     },
#     {
#       "given": "User data is being transmitted between the client and the server, or between internal services.",
#       "when": "The data transfer occurs.",
#       "then": "All data in transit is encrypted using industry-standard protocols (e.g., TLS) to ensure confidentiality."
#     },
#     {
#       "given": "A user submits a request to delete all their personal data.",
#       "when": "The system processes the user's deletion request.",
#       "then": "All identifiable personal data associated with the user is permanently and irrevocably removed from the system in compliance with GDPR."
#     },
#     {
#       "given": "A user submits a request to access their personal data.",
#       "when": "The system processes the user's access request.",
#       "then": "The system provides the user with a copy of their personal data in a structured, commonly used, and machine-readable format in compliance with GDPR."
#     },
#     {
#       "given": "Sensitive user data is collected and processed.",
#       "when": "The system determines the appropriate storage location based on data residency rules.",
#       "then": "The data is stored within the designated geographic region to comply with GDPR data residency requirements."
#     },
#     {
#       "given": "An enterprise user attempts to log in to the platform.",
#       "when": "They authenticate using their organization's configured Single Sign-On (SSO) provider.",
#       "then": "The user is successfully logged in without needing to create or manage separate platform credentials."
#     },
#     {
#       "given": "An enterprise administrator wants to gain insights into content performance or team activity.",
#       "when": "The administrator uses the custom reporting interface to define specific metrics, filters, and timeframes.",
#       "then": "The system generates a custom report displaying the requested data."
#     },
#     {
#       "given": "An enterprise team has enabled a specific compliance pack (e.g., HIPAA, SOC2).",
#       "when": "A user attempts to perform an action that might violate the compliance pack's rules.",
#       "then": "The system automatically enforces the rules defined by the compliance pack, either preventing the action or triggering a review process."
#     },
#     {
#       "given": "A user has created a content item and connected their LinkedIn profile using the v1 API.",
#       "when": "The user schedules or initiates publishing of the content item to LinkedIn.",
#       "then": "The content item is successfully posted to the user's LinkedIn profile using the LinkedIn API v1."
#     },
#     {
#       "given": "The system architecture is designed with modularity for social media integrations.",
#       "when": "New platform connectors for X, Instagram, or YouTube are required in the future.",
#       "then": "New platform connectors can be developed and integrated without requiring significant changes to the core content management or publishing systems."
#     },
#     {
#       "given": "A new data model is introduced into the system schema.",
#       "when": "The system validates the schema integrity.",
#       "then": "The data model must explicitly define a relation to either a 'User', 'Team', or 'Workspace' entity."
#     },
#     {
#       "given": "A system entity requires contextual ownership or scope.",
#       "when": "The entity is created or associated with an organizational unit.",
#       "then": "It must be possible to link the entity via a 'teamId' or 'workspaceId', with appropriate nullability as defined."
#     },
#     {
#       "given": "A user attempts to perform an action within a specific 'Team' or 'Workspace'.",
#       "when": "The system determines the user's access permissions.",
#       "then": "The user's 'UserRole' should be evaluated in the context of their associated 'Team' or 'Workspace' membership."
#     },
#     {
#       "given": "Content in the system requires localization for different audiences.",
#       "when": "A translation record is created or retrieved.",
#       "then": "The translation record must be linked to a specific 'locale' and can optionally be associated with a 'Workspace' for workspace-specific translations."
#     },
#     {
#       "given": "A new user account is provisioned in the system.",
#       "when": "The user's core information is stored.",
#       "then": "The system must create a 'User' entity with a unique 'id', a unique 'email', an optional 'name' and 'displayName', a default 'role' of 'EDITOR', and track 'createdAt' and 'updatedAt' timestamps."
#     },
#     {
#       "given": "A new team is established within the system.",
#       "when": "The team's foundational data is configured.",
#       "then": "The system must create a 'Team' entity with a unique 'id', a mandatory 'name', an optional unique 'slug', an optional 'ownerId' linked to a 'User', a default 'plan' of 'NORMAL', a default 'seatCount' of '1', and track 'createdAt' and 'deletedAt' timestamps."
#     },
#     {
#       "given": "An authenticated user",
#       "when": "The user creates a new team",
#       "then": "A 'Team' record is created, and the user is designated as the team's owner"
#     },
#     {
#       "given": "An existing team",
#       "when": "An authorized administrator requests to soft-delete the team",
#       "then": "The 'deleted_at' field of the 'Team' record is populated with the current timestamp"
#     },
#     {
#       "given": "A team and an uninvited user",
#       "when": "An authorized team member invites the user to the team with a specified role",
#       "then": "A 'TeamMember' record is created with the user, team, specified role, and a default status of 'invited'"
#     },
#     {
#       "given": "A user has an 'invited' status in a 'TeamMember' record",
#       "when": "The invited user accepts the team invitation",
#       "then": "The 'status' field of the 'TeamMember' record is updated to 'accepted', and 'acceptedAt' is populated"
#     },
#     {
#       "given": "A user is already a member of a specific team",
#       "when": "An attempt is made to add the same user to the same team again",
#       "then": "The system prevents the creation of a duplicate 'TeamMember' record, enforcing the unique constraint on 'teamId' and 'userId'"
#     },
#     {
#       "given": "A team and a user are available",
#       "when": "An authorized user assigns a specific 'seatType' to the user within the team",
#       "then": "A 'Seat' record is created, linking the user and team, with the specified 'seatType' and 'assignedAt' timestamp"
#     },
#     {
#       "given": "A user already has a seat assigned within a specific team",
#       "when": "An attempt is made to assign another seat to the same user within the same team",
#       "then": "The system prevents the creation of a duplicate 'Seat' record, enforcing the unique constraint on 'teamId' and 'userId'"
#     },
#     {
#       "given": "An existing team",
#       "when": "An authorized user creates a new workspace for the team with a name and optional slug",
#       "then": "A 'Workspace' record is created, associated with the team, and 'createdAt' is populated"
#     },
#     {
#       "given": "An existing workspace",
#       "when": "An authorized user requests to soft-delete the workspace",
#       "then": "The 'deletedAt' field of the 'Workspace' record is populated with the current timestamp"
#     },
#     {
#       "given": "An existing user and an existing workspace",
#       "when": "An authorized user links the user to the workspace with a specific 'permissionSet'",
#       "then": "A 'UserWorkspace' record is created, linking the user to the workspace and storing the provided 'permissionSet'"
#     },
#     {
#       "given": "A user is already linked to a specific workspace",
#       "when": "An attempt is made to link the same user to the same workspace again",
#       "then": "The system prevents the creation of a duplicate 'UserWorkspace' record, enforcing the unique constraint on 'userId' and 'workspaceId'"
#     },
#     {
#       "given": "An administrator wishes to configure an external identity provider",
#       "when": "The administrator creates an 'IdentityProvider' record with a 'providerType' and 'configJson'",
#       "then": "A new 'IdentityProvider' record is stored, including its configuration details"
#     },
#     {
#       "given": "An existing identity provider and an existing team",
#       "when": "An authorized user links the identity provider to the team",
#       "then": "An 'IdpLink' record is created, associating the team with the identity provider"
#     },
#     {
#       "given": "An authenticated user wants to connect their LinkedIn account",
#       "when": "The user successfully authorizes the application to access their LinkedIn profile",
#       "then": "A 'LinkedInProfile' record is created, associated with the user, storing their LinkedIn profile ID, display name, and encrypted access tokens"
#     },
#     {
#       "given": "A user wants to connect their social media profile.",
#       "when": "The user authorizes the application to access their LinkedIn profile data.",
#       "then": "A new 'LinkedInProfile' record is created, linked to the user, with the 'linkedinProfileId', 'scope', and a 'createdAt' timestamp. The 'expiresAt' and 'lastSyncAt' fields are populated based on the authorization."
#     },
#     {
#       "given": "An existing 'LinkedInProfile' for a user has an 'expiresAt' timestamp.",
#       "when": "The system attempts to perform an action using that LinkedIn profile.",
#       "then": "The system verifies that the current time is before the 'expiresAt' timestamp to ensure the profile is still valid. If expired, it should prompt for re-authorization."
#     },
#     {
#       "given": "A team administrator wants to define a new brand voice for their team.",
#       "when": "The administrator provides a 'name', optional 'description', and 'voiceJson' for the brand voice.",
#       "then": "A new 'BrandVoice' record is created, associated with the team, with the provided details and a 'createdAt' timestamp."
#     },
#     {
#       "given": "A new user registers for the service.",
#       "when": "The system initiates the onboarding process for the user.",
#       "then": "An 'OnboardingProfile' record is created for the user, with a 'userId' and 'createdAt' timestamp, and 'onboardedAt' is null."
#     },
#     {
#       "given": "An 'OnboardingProfile' exists for a user, and a 'BrandVoice' is available.",
#       "when": "The user selects a specific brand voice during their onboarding process.",
#       "then": "The 'brandVoiceId' field in the user's 'OnboardingProfile' is updated to link to the selected 'BrandVoice'."
#     },
#     {
#       "given": "An administrator wants to create a new role for managing permissions.",
#       "when": "The administrator specifies a 'name' and an optional 'description' for the new role, and optionally links it to a 'teamId' or 'workspaceId'.",
#       "then": "A new 'Role' record is created with a unique ID, the provided details, and a 'createdAt' timestamp."
#     },
#     {
#       "given": "The system needs to define a new capability that can be granted.",
#       "when": "A new permission is created with a unique 'code' and an optional 'description'.",
#       "then": "A 'Permission' record is created with the specified 'code' and 'description', and the system ensures the 'code' is unique."
#     },
#     {
#       "given": "An existing 'Role' and an existing 'Permission'.",
#       "when": "An administrator grants the permission to the role.",
#       "then": "A 'RolePermission' record is created, linking the 'roleId' and 'permissionId', with a 'createdAt' timestamp. The system prevents creating a duplicate entry for the same role and permission."
#     },
#     {
#       "given": "An existing 'User' and an existing 'Role'.",
#       "when": "An administrator assigns the role to the user, optionally specifying a 'scopeType' and 'scopeId'.",
#       "then": "A 'UserRoleRelation' record is created, linking the 'userId' and 'roleId', along with the optional scope details and a 'createdAt' timestamp. The system prevents creating a duplicate assignment for the same user, role, and scope combination."
#     },
#     {
#       "given": "A user wants to create a reusable content template.",
#       "when": "The user provides a 'title', 'type', and optionally a 'schemaJson' for the template.",
#       "then": "A new 'Template' record is created, owned by the user ('ownerId'), with the provided details and a 'createdAt' timestamp. The 'searchTsv' field is populated for full-text search."
#     },
#     {
#       "given": "An existing 'Template' and a 'Team' or 'Workspace'.",
#       "when": "The template is configured to be available within a specific team or workspace.",
#       "then": "The 'teamId' or 'workspaceId' field of the 'Template' record is updated to link it to the designated entity."
#     },
#     {
#       "given": "A user is logged in and operating within a specific workspace.",
#       "when": "The user creates a new template, providing its 'ownerId', 'workspaceId', and 'type'.",
#       "then": "A new Template record is stored with 'sharedScope' set to 'private', 'version' to 1, and 'createdAt'/'updatedAt' timestamps initialized."
#     },
#     {
#       "given": "Multiple templates exist in the system, each with a 'searchTsv' field.",
#       "when": "A user performs a search query.",
#       "then": "The system filters and returns templates whose 'searchTsv' field matches the query."
#     },
#     {
#       "given": "An existing template and a valid target workspace.",
#       "when": "An authorized user shares the template with the target workspace.",
#       "then": "A 'TemplateShare' record is created, linking the template, the target workspace, and the user who shared it."
#     },
#     {
#       "given": "An existing template and a registered publisher user.",
#       "when": "The publisher lists the template on the marketplace, optionally specifying pricing.",
#       "then": "A 'TemplateMarketplaceItem' record is created, associating the template, publisher, and marketplace details including pricing and an initial status."
#     },
#     {
#       "given": "An authenticated user.",
#       "when": "The user creates a new 'ContentItem', specifying its 'type' and 'ownerId', and optionally 'title' and 'body'.",
#       "then": "A 'ContentItem' record is created with 'status' set to 'DRAFT', 'version' to 1, and 'createdAt'/'updatedAt' timestamps initialized."
#     },
#     {
#       "given": "An existing 'ContentItem' with a specific version.",
#       "when": "The 'title', 'body', 'tags', or 'metadata' of the content item are updated.",
#       "then": "The 'ContentItem''s 'updatedAt' timestamp is updated, its 'version' is incremented, and the changes are persisted."
#     },
#     {
#       "given": "An existing 'ContentItem'.",
#       "when": "An authorized user requests to delete the 'ContentItem'.",
#       "then": "The 'deletedAt' field of the 'ContentItem' is populated with the current timestamp, marking it as soft-deleted without physically removing the record."
#     },
#     {
#       "given": "A user wants to create a new content item",
#       "when": "The user provides the necessary content details, workspace, team, owner, and an initial content body",
#       "then": "A new ContentItem record is created, an initial ContentVersion is recorded for it, and it is assigned to the specified workspace, team, and owner."
#     },
#     {
#       "given": "An existing ContentItem",
#       "when": "An author submits changes to the content body, along with a change reason and an optional version label",
#       "then": "A new ContentVersion record is created, linked to the ContentItem, storing the updated body, author, change reason, and version label, while preserving previous versions."
#     },
#     {
#       "given": "An existing ContentItem and a file to be attached",
#       "when": "A user uploads the file and associates it with the ContentItem, specifying its filename, content type, size, and storage path",
# ...
#     },
#     {
#       "given": "A customer's invoice has passed its due date without payment.",
#       "when": "The system detects the overdue invoice during its dunning process.",
#       "then": "The system should initiate automated dunning actions, such as sending reminder emails to the customer."
#     },
#     {
#       "given": "A specific system event occurs (e.g., password reset, subscription change).",
#       "when": "The system triggers a notification for that event.",
#       "then": "A notification should be delivered to the user via their preferred channel (e.g., email, in-app)."
#     },
#     {
#       "given": "A user is logged in.",
#       "when": "The user navigates to their notification settings and updates their preferences for receiving certain types of messages.",
#       "then": "The user's notification preferences should be saved and respected for future system messages."
#     },
#     {
#       "given": "A marketing user is logged in to the email campaign management section.",
#       "when": "The user uses the WYSIWYG editor to create a new email template with dynamic variables.",
#       "then": "The email template should be saved, and the dynamic variables should correctly render personalized content during sending."
#     },
#     {
#       "given": "An administrator performs a critical configuration change.",
#       "when": "The administrator saves the configuration change.",
#       "then": "An immutable record of the administrator's action, including who, what, and when, should be added to the audit log."
#     },
#     {
#       "given": "An administrator needs to review system activity.",
#       "when": "The administrator accesses the audit log and applies filters for a specific user and date range.",
#       "then": "The audit log should display relevant activity records matching the applied filters."
#     },
#     {
#       "given": "New software dependencies are introduced to the platform.",
#       "when": "The system performs its scheduled vulnerability scan.",
#       "then": "The vulnerability scan should identify and report any known vulnerabilities in the new dependencies."
#     },
#     {
#       "given": "Sensitive data is being stored at rest in the database.",
#       "when": "The data is written to disk.",
#       "then": "The data should be automatically encrypted using platform-managed encryption keys."
#     },
#     {
#       "given": "The system has active encryption keys.",
#       "when": "The scheduled key rotation policy is triggered.",
#       "then": "The system should automatically generate and switch to new encryption keys, and securely archive the old ones."
#     },
#     {
#       "given": "The platform is configured for scheduled backups.",
#       "when": "The scheduled time for a full backup arrives.",
#       "then": "A complete backup of all critical data and configurations should be performed and stored in a geo-redundant location."
#     },
#     {
#       "given": "A critical system component experiences an error.",
#       "when": "The error event occurs.",
#       "then": "The system should automatically log the error, and an alert should be triggered for the operations team."
#     },
#     {
#       "given": "A user wants to understand product performance.",
#       "when": "The user accesses the metrics dashboard.",
#       "then": "The dashboard should display real-time and historical data for key performance indicators and application health."
#     },
#     {
#       "given": "An administrator needs insights into feature adoption.",
#       "when": "The administrator views a pre-built analytics dashboard.",
#       "then": "The dashboard should present key metrics and trends related to feature usage and user engagement."
#     },
#     {
#       "given": "A user logs into the application.",
#       "when": "The application loads the user's dashboard.",
#       "then": "The dashboard should display personalized widgets and data relevant to the user's role and preferences."
#     },
#     {
#       "given": "A user is viewing a list of entities (e.g., customers, projects).",
#       "when": "The user enters a keyword into the global search bar.",
#       "then": "The system should return relevant search results across all accessible entities, ranked by relevance."
#     },
#     {
#       "given": "A developer needs to integrate with the platform's API.",
#       "when": "The developer creates a new API key in the developer portal.",
#       "then": "A unique API key should be generated and associated with the developer's account, with configurable permissions."
#     },
#     {
#       "given": "An external system is subscribed to a webhook for a 'New User' event.",
#       "when": "A new user account is successfully created in the platform.",
#       "then": "A webhook notification containing the new user's details should be sent to the subscribed external system."
#     },
#     {
#       "given": "An administrator needs to synchronize customer data from an external CRM.",
#       "when": "The administrator configures and enables a pre-built CRM connector.",
#       "then": "The connector should establish a connection to the CRM, map data fields, and schedule data synchronization."
#     },
#     {
#       "given": "A multi-step approval process is defined in the workflow engine.",
#       "when": "A user submits a request that triggers this approval workflow.",
#       "then": "The workflow engine should initiate the process, assign the first approval step, and notify the designated approver."
#     },
#     {
#       "given": "A user is logged in.",
#       "when": "The user creates a new task, assigns it to a colleague, and sets a priority.",
#       "then": "The new task should be recorded in the system, assigned to the colleague, and appear in relevant task lists."
#     },
#     {
#       "given": "A sales representative is logged in.",
#       "when": "The sales representative creates a new contact record for a prospect.",
#       "then": "A new contact record should be created, capturing essential information like name, email, and company."
#     },
#     {
#       "given": "A customer encounters an issue with the product.",
#       "when": "The customer submits a support ticket via the helpdesk portal.",
#       "then": "A new support ticket should be created, routed to the appropriate support queue, and the customer should receive a confirmation."
#     },
#     {
#       "given": "A website visitor needs immediate assistance.",
#       "when": "The visitor initiates a live chat session via the in-app widget.",
#       "then": "A chat session should be established, and the visitor should be connected to an available support agent or chatbot."
#     },
#     {
#       "given": "A user needs to store an important document.",
#       "when": "The user uploads a document to the document management system.",
#       "then": "The document should be securely stored, a new version created, and access permissions applied."
#     },
#     {
#       "given": "A user wants to share a large file with a colleague.",
#       "when": "The user uploads the file to the platform's file storage.",
#       "then": "The file should be stored, and a secure, time-limited sharing URL should be generated for the user."
#     },
#     {
#       "given": "An administrator needs to onboard existing user data.",
#       "when": "The administrator initiates a data import process using a CSV file and maps the columns.",
#       "then": "The system should validate the data, import valid records, and provide a report on any failed imports."
#     },
#     {
#       "given": "A new feature is developed but not yet released to all users.",
#       "when": "An administrator enables a feature flag for a specific target group of beta users.",
#       "then": "Only users within the designated beta group should see and access the new feature in the application."
#     },
#     {
#       "given": "Product managers want to test two different UI variants.",
#       "when": "An administrator configures an A/B test, defines two variants, and sets a traffic allocation.",
#       "then": "The system should randomly assign users to one of the variants and start collecting performance data for each."
#     },
#     {
#       "given": "A user whose native language is French is using the application.",
#       "when": "The user changes their language preference to 'French'.",
#       "then": "All user interface text and localized content should be displayed in French."
#     },
#     {
#       "given": "A user is logged in.",
#       "when": "The user navigates to their personal settings and updates their UI theme preference.",
#       "then": "The selected UI theme should be applied immediately and persist across sessions for that user."
#     },
#     {
#       "given": "A user is viewing a document.",
#       "when": "The user adds a comment to a specific section of the document and mentions a colleague.",
#       "then": "The comment should be saved, the mentioned colleague should receive a notification, and the comment should be visible in the document's discussion thread."
#     },
#     {
#       "given": "A user needs to schedule a meeting with a team member.",
#       "when": "The user uses the in-app calendar to find available slots and books a meeting.",
#       "then": "The meeting should be added to both users' calendars, and both should receive an invitation and reminder."
#     },
#     {
#       "given": "A physical product inventory is being tracked.",
#       "when": "The stock level for a specific SKU drops below its reorder point.",
#       "then": "The system should automatically generate a reorder alert or initiate a procurement request for that SKU."
#     },
#     {
#       "given": "A sales team member is preparing a sales proposal.",
#       "when": "The sales team member generates a new quote within the system based on product catalog items.",
#       "then": "A professional quote document should be generated, including product details, pricing, and terms."
#     },
#     {
#       "given": "A department needs to purchase new office supplies.",
#       "when": "A user creates a new purchase order (PO) in the procurement system and submits it for approval.",
#       "then": "The PO should be created, assigned a unique ID, and enter the predefined approval workflow."
#     },
#     {
#       "given": "An HR administrator is logged in.",
#       "when": "The HR administrator creates a new employee profile in the system.",
#       "then": "A comprehensive employee record should be established, including personal details, job role, and onboarding checklist."
#     },
#     {
#       "given": "An employee is working on a project task.",
#       "when": "The employee uses the time tracking feature to log their work hours for the task.",
#       "then": "The logged time should be recorded against the specific task and become available for timesheet submission."
#     },
#     {
#       "given": "Employee timesheets have been submitted and approved for a pay period.",
#       "when": "The payroll system initiates the salary calculation process.",
#       "then": "The system should calculate gross pay, deductions, and net pay for each employee based on their salary rules and statutory compliance."
#     },
#     {
#       "given": "An API consumer is making repeated requests to the platform API.",
#       "when": "The API consumer exceeds their defined rate limit within a specific time window.",
#       "then": "The system should reject subsequent API requests from that consumer with a 'Too Many Requests' error (HTTP 429)."
#     },
#     {
#       "given": "A customer has an active Service Level Agreement (SLA) for uptime.",
#       "when": "The system detects an outage that causes service unavailability for the customer, breaching the SLA threshold.",
#       "then": "The system should automatically trigger an alert to the operations team and log the SLA breach event for potential credit calculation."
#     },
#     {
#       "given": "A new user registers for the service.",
#       "when": "The user reviews and accepts the Privacy Policy and Cookie Consent terms.",
#       "then": "The system should record the user's consent and apply the privacy preferences accordingly."
#     },
#     {
#       "given": "A compliance officer is conducting an internal audit.",
#       "when": "The officer accesses the Governance, Risk & Compliance (GRC) module to review a specific policy.",
#       "then": "The system should display the latest version of the policy, along with its history and associated controls."
#     },
#     {
#       "given": "The application experiences a sudden surge in user traffic.",
#       "when": "The system's monitoring detects the increased load exceeding predefined thresholds.",
#       "then": "The system should automatically trigger autoscaling policies to provision additional resources to handle the demand."
#     },
#     {
#       "given": "A developer is building an integration with the platform.",
#       "when": "The developer accesses the Developer Portal and consults the interactive API documentation.",
#       "then": "The documentation should provide up-to-date API endpoints, request/response examples, and allow making test calls directly."
#     },
#     {
#       "given": "A user needs to extend the platform's functionality.",
#       "when": "The user browses the marketplace and installs a third-party application.",
#       "then": "The application should be installed, request necessary permissions, and integrate seamlessly with the platform's features."
#     },
#     {
#       "given": "An auditor requests a report of all user access activities for the last quarter.",
#       "when": "An administrator generates an 'User Access Report' for the specified period.",
#       "then": "The system should produce an exportable report detailing user logins, logouts, and access attempts."
#     },
#     {
#       "given": "A customer has completed a purchase.",
#       "when": "The system presents an NPS survey to the customer.",
#       "then": "The customer should be able to provide feedback, and their NPS score should be recorded and contribute to product analytics."
#     },
#     {
#       "given": "A new user signs up and logs in for the first time.",
#       "when": "The system detects that the user is new.",
#       "then": "The system should automatically launch a guided tour to introduce core features and assist with initial setup."
#     },
#     {
#       "given": "A user interacts with various features within the application.",
#       "when": "The user clicks on buttons, navigates sections, and submits forms.",
#       "then": "The system should track these interactions as telemetry data, recording feature usage and user-level metrics."
#     },
#     {
#       "given": "A tenant administrator wishes to migrate their data to another service.",
#       "when": "The administrator requests a data export for their tenant's data in a standard format.",
#       "then": "The system should generate an encrypted export file containing all specified tenant data, ready for download."
#     },
#     {
#       "given": "A customer is selecting a product plan.",
#       "when": "The customer applies a promotional coupon code during the checkout process.",
#       "then": "The pricing engine should validate the coupon, apply the discount to the total cost, and display the revised price."
#     },
#     {
#       "given": "A platform operator is managing global system settings.",
#       "when": "The operator logs into the Superadmin Console.",
#       "then": "The console should display a comprehensive overview of global health status, incident summaries, and tenant management options."
#     },
#     {
#       "given": "A critical service outage has occurred.",
#       "when": "An incident manager creates a new incident record in the system.",
#       "then": "The incident should be logged, a public status page should be updated to reflect the outage, and subscribers should be notified."
#     },
#     {
#       "given": "A user submits a request that requires manager approval.",
#       "when": "The request is submitted.",
#       "then": "The system should automatically route the request to the designated manager for approval and notify them."
#     }
#   ]
# }

# %% [markdown]
# # SPLIT into different Categories

# %%
import os
import json
from pathlib import Path

# Load the generated master JSON
with open("bdd_output_gemini.json", "r", encoding="utf-8") as f:
    bdd_json = json.load(f)

# Create an output folder for the split files
output_dir = Path("bdd_output_split")
output_dir.mkdir(exist_ok=True)

# Define keywords to detect each domain
domain_map = {
    "auth": ["login", "signup", "password", "mfa", "authenticate", "logout"],
    "onboarding": ["onboard", "setup", "profile", "introduction"],
    "billing": ["payment", "invoice", "subscription", "refund", "billing", "checkout"],
    "content": ["post", "article", "draft", "generate", "ai", "editor", "caption"],
    "analytics": ["dashboard", "metrics", "insights", "report", "tracking"],
    "team": ["team", "workspace", "member", "invite"],
    "admin": ["admin", "role", "permission", "configuration", "superadmin"],
    "notifications": ["notification", "email", "message", "alert"],
    "workflow": ["workflow", "approval", "task", "automation"],
    "integration": ["api", "webhook", "integration", "connector"],
    "security": ["compliance", "encryption", "access", "tls", "policy"]
}

def detect_domain(scenario):
    """
    Detect which domain a scenario belongs to based on keyword matching.
    """
    text = (
        scenario.get("given", "") + " " +
        scenario.get("when", "") + " " +
        scenario.get("then", "")
    ).lower()

    # Less pythonic, more explicit
    for domain, keywords in domain_map.items():
        for keyword in keywords:
            if keyword in text:
                return domain

    return "misc"  # fallback if no match

# Keep a counter of how many scenarios per domain
domain_counts = {}

# Split and save scenarios by domain
for scenario in bdd_json.get("features", []):
    domain = detect_domain(scenario)
    file_path = output_dir / f"{domain}.json"

    # Load existing data if file already exists
    if file_path.exists():
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
    else:
        data = {"features": []}

    # Add scenario and save back
    data["features"].append(scenario)
    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)

    # Count how many scenarios per domain
    if domain in domain_counts:
        domain_counts[domain] += 1
    else:
        domain_counts[domain] = 1

# === Summary Printout ===
print("\n✅ BDD scenarios split into domain-based JSON files inside /bdd_output_split/\n")
print("📊 Summary by category:\n")
for domain, count in sorted(domain_counts.items()):
    print(f"  • {domain:<15} → {count} scenarios")
print(f"\n📁 Total categories: {len(domain_counts)}")
print(f"🧩 Total scenarios:  {sum(domain_counts.values())}")
# Out:
# ✅ BDD scenarios split into domain-based JSON files inside /bdd_output_split/
#
# 📊 Summary by category:
#
#   • admin           → 61 scenarios
#   • analytics       → 30 scenarios
#   • auth            → 96 scenarios
#   • billing         → 148 scenarios
#   • content         → 372 scenarios
#   • integration     → 25 scenarios
#   • misc            → 115 scenarios
#   • notifications   → 15 scenarios
#   • onboarding      → 51 scenarios
#   • security        → 27 scenarios
#   • team            → 167 scenarios
#   • workflow        → 21 scenarios
#
# 📁 Total categories: 12
# 🧩 Total scenarios:  1128

# %% [markdown]
# # Inferences
#
# ## Option 1: Split After Generation (Keyword-Based)
#
# **How it works:**
#
# * Generate all BDDs into one JSON file.
# * Use keyword matching (e.g., `"login" → auth`, `"payment" → billing`) to split into logical JSON files.
#
# **Pros:**
#
# * Fast and simple implementation
# * No extra API calls (cost-efficient)
# * Deterministic output (no randomness)
# * Easy to debug and adjust
# * Low latency, good for bulk PRD processing
#
# **Cons:**
#
# * Requires manual keyword maintenance
# * May misclassify complex sentences
# * No real semantic understanding
#
# <br>
#
# ---
#
# <br>
#
# ## Option 2: Modify JSON and Ask LLM to Classify (LLM-Assisted)
#
# **How it works:**
#
# * Ask the LLM to include a `"domain"` field along with each scenario (`Given`, `When`, `Then`).
#
# **Example output:**
#
# ```json
# {
#   "given": "A user has valid credentials",
#   "when": "They attempt to log in",
#   "then": "The system authenticates them",
#   "domain": "auth"
# }
# ```
#
# **Pros:**
#
# * Understands semantic meaning beyond keywords
# * Adapts as domains evolve
# * Simplifies post-processing (group by domain directly)
#
# **Cons:**
#
# * Higher API token cost
# * Slightly slower generation
# * May produce inconsistent domain labels
# * May fill the context window faster when we explicitly mention the domains in the prompt
#
# <br>
#
# ---
#
# <br>
#
# ## Which Approach Is Better?
#
# **If prototyping or building early pipeline:**
#
# * Keyword-based splitting is better
# * Easier to tune and debug
# * Fast, predictable, and cheap
# * “Domain” field can be added later
#
# **If optimizing for production automation:**
#
# * LLM-based tagging is better
# * More flexible and semantically accurate
# * Scales across complex or ambiguous PRDs
#
# <br>
#
# ---
#
# <br>
#
# ## Hybrid Approach
#
# Use both approaches together:
#
# ```python
# if "domain" in scenario and scenario["domain"]:
#     domain = normalize_domain(scenario["domain"])
# else:
#     domain = detect_domain_using_keywords(scenario)
# ```
#
# * Combines LLM’s semantic power with keyword fallback
# * Balances accuracy, cost, and stability
#
# <br>
#
# ---
#
# <br>
#
#
# ## Summary
#
# * **For rapid prototyping:** use keyword-based post-split
# * **For production-level accuracy:** use LLM-generated `domain`
# * **Best overall:** hybrid approach (LLM + keyword fallback)
